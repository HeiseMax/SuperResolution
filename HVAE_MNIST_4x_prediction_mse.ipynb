# %%
import torch
from torchinfo import summary
import torch.optim as optim
from torch.nn import MSELoss
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader


from utils.metrics import validation_scores
from models.prediction.HVAE import ConditionalHierarchicalVAE
from utils.datasets import MNIST_SR
from utils.utils import gaussian_kl


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
num_epochs = 100
batch_size = 512
scalefactor = 4

path = f"E:/GNN/experiments/trained_models/trained_models/HVAE_MNIST_{scalefactor}x_prediction_mse.pth"

latent_dims = [64, 128, 256]
condition_dims = [32, 64]
channels = [16, 32, 64, 128]
cond_channels = [16, 32]
in_channels = 1
cond_base_width = 32 // scalefactor
model = ConditionalHierarchicalVAE(in_channels=in_channels,
                          #latent_dims=latent_dims,
                          channels=channels,
                          cond_channels=cond_channels,
                          condition_dims=condition_dims,
                          cond_base_width=cond_base_width
                          ).to(device)
print(model.sample(torch.randn(1, in_channels, cond_base_width, cond_base_width).to(device)).shape)
summary(model, input_size=[(1, in_channels, 32, 32), (1, in_channels, cond_base_width, cond_base_width)])
# Out:
# torch.Size([1, 1, 32, 32])
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ConditionalHierarchicalVAE                    [1, 1, 32, 32]            --
# ├─ConditionalHierarchicalEncoder: 1-1         [1, 64]                   --
# │    └─Conv2d: 2-1                            [1, 16, 32, 32]           32
# │    └─Conv2d: 2-2                            [1, 32, 16, 16]           8,224
# │    └─Conv2d: 2-3                            [1, 64, 8, 8]             32,832
# │    └─Conv2d: 2-4                            [1, 128, 4, 4]            131,200
# │    └─Linear: 2-5                            [1, 64]                   131,136
# │    └─Linear: 2-6                            [1, 64]                   131,136
# │    └─Linear: 2-7                            [1, 128]                  524,416
# │    └─Linear: 2-8                            [1, 128]                  524,416
# │    └─Linear: 2-9                            [1, 256]                  2,097,408
# │    └─Linear: 2-10                           [1, 256]                  2,097,408
# ├─ConditionalHierarchicalLREncoder: 1-2       [1, 32]                   --
# │    └─Conv2d: 2-11                           [1, 16, 8, 8]             32
# │    └─Conv2d: 2-12                           [1, 32, 4, 4]             8,224
# │    └─Linear: 2-13                           [1, 32]                   16,416
# │    └─Linear: 2-14                           [1, 64]                   65,600
# ├─ConditionalHierarchicalDecoder: 1-3         [1, 1, 32, 32]            --
# │    └─Linear: 2-15                           [1, 2048]                 133,120
# │    └─Linear: 2-16                           [1, 4096]                 528,384
# │    └─Linear: 2-17                           [1, 8192]                 2,105,344
# │    └─Linear: 2-18                           [1, 2048]                 67,584
# │    └─Linear: 2-19                           [1, 4096]                 266,240
# │    └─ConvTranspose2d: 2-20                  [1, 64, 8, 8]             262,208
# │    └─ConvTranspose2d: 2-21                  [1, 32, 16, 16]           65,568
# │    └─ConvTranspose2d: 2-22                  [1, 16, 32, 32]           8,208
# │    └─Conv2d: 2-23                           [1, 1, 32, 32]            17
# ===============================================================================================
# Total params: 9,205,153
# Trainable params: 9,205,153
# Non-trainable params: 0
# Total mult-adds (M): 57.15
# ===============================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.67
# Params size (MB): 36.82
# Estimated Total Size (MB): 37.49
# ===============================================================================================

# %%
train_dataset = MNIST_SR(scale_factor=scalefactor, split='train')
test_dataset = MNIST_SR(scale_factor=scalefactor, split='test')

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
num_train_data = len(train_dataset)
print(f"Dataset Loaded: {len(train_dataset)} training samples, {len(test_dataset)} validation samples")
# Out:
# Dataset Loaded: 60000 training samples, 10000 validation samples

# %%
# Adam opt
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = MSELoss()
# Learning Rate Scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.9)

# %%
loss_list = []
recon_loss_list = []
kl_loss_list = []

# %%
kl_weight = 1000

for epoch in range(num_epochs):
    model.train()
    
    total_loss = 0
    total_recon_loss = 0
    total_kl_loss = 0

    for HR, LR in train_loader:
        optimizer.zero_grad()

        recon_imgs, latents = model(HR, LR)

        recon_loss = criterion(recon_imgs, HR)
        kl_loss = 0
        for mu, logvar in latents:
            kl_loss += torch.mean(gaussian_kl(mu, logvar, torch.zeros_like(mu), torch.zeros_like(logvar)))
        loss = recon_loss + kl_weight * kl_loss

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        total_recon_loss += recon_loss.item()
        total_kl_loss += kl_loss.item()

    scheduler.step()    

    print(f"Epoch [{epoch+1}/{num_epochs}] | Loss: {total_loss:.6f} | Recon Loss: {total_recon_loss:.6f} | KL Loss: {total_kl_loss:.6f}")
    loss_list.append(total_loss)
    recon_loss_list.append(total_recon_loss)
    kl_loss_list.append(total_kl_loss)
# Out:
# Epoch [1/100] | Loss: 8672.362535 | Recon Loss: 7.462521 | KL Loss: 8.664900
# Epoch [2/100] | Loss: 58.146091 | Recon Loss: 4.712564 | KL Loss: 0.053434
# Epoch [3/100] | Loss: 33.936221 | Recon Loss: 2.610991 | KL Loss: 0.031325
# Epoch [4/100] | Loss: 24.073349 | Recon Loss: 2.007227 | KL Loss: 0.022066
# Epoch [5/100] | Loss: 50.902630 | Recon Loss: 1.736620 | KL Loss: 0.049166
# Epoch [6/100] | Loss: 78.597067 | Recon Loss: 1.568304 | KL Loss: 0.077029
# Epoch [7/100] | Loss: 12.554091 | Recon Loss: 1.457836 | KL Loss: 0.011096
# Epoch [8/100] | Loss: 65.659780 | Recon Loss: 1.385096 | KL Loss: 0.064275
# Epoch [9/100] | Loss: 42.921539 | Recon Loss: 1.332128 | KL Loss: 0.041589
# Epoch [10/100] | Loss: 8.582547 | Recon Loss: 1.288766 | KL Loss: 0.007294
# Epoch [11/100] | Loss: 41.436657 | Recon Loss: 1.250855 | KL Loss: 0.040186
# Epoch [12/100] | Loss: 43.163391 | Recon Loss: 1.228436 | KL Loss: 0.041935
# Epoch [13/100] | Loss: 9.132680 | Recon Loss: 1.198141 | KL Loss: 0.007935
# Epoch [14/100] | Loss: 5.693840 | Recon Loss: 1.176883 | KL Loss: 0.004517
# Epoch [15/100] | Loss: 22.254411 | Recon Loss: 1.160474 | KL Loss: 0.021094
# Epoch [16/100] | Loss: 5.145305 | Recon Loss: 1.139615 | KL Loss: 0.004006
# Epoch [17/100] | Loss: 20.291027 | Recon Loss: 1.126199 | KL Loss: 0.019165
# Epoch [18/100] | Loss: 43.087741 | Recon Loss: 1.115529 | KL Loss: 0.041972
# Epoch [19/100] | Loss: 5.240891 | Recon Loss: 1.097881 | KL Loss: 0.004143
# Epoch [20/100] | Loss: 3.745235 | Recon Loss: 1.087631 | KL Loss: 0.002658
# Epoch [21/100] | Loss: 3.648359 | Recon Loss: 1.077979 | KL Loss: 0.002570
# Epoch [22/100] | Loss: 3.359285 | Recon Loss: 1.068803 | KL Loss: 0.002290
# Epoch [23/100] | Loss: 4.709160 | Recon Loss: 1.059606 | KL Loss: 0.003650
# Epoch [24/100] | Loss: 22.194019 | Recon Loss: 1.052672 | KL Loss: 0.021141
# Epoch [25/100] | Loss: 2.913148 | Recon Loss: 1.043556 | KL Loss: 0.001870
# Epoch [26/100] | Loss: 2.895726 | Recon Loss: 1.036399 | KL Loss: 0.001859
# Epoch [27/100] | Loss: 15.937187 | Recon Loss: 1.030818 | KL Loss: 0.014906
# Epoch [28/100] | Loss: 2.584476 | Recon Loss: 1.024209 | KL Loss: 0.001560
# Epoch [29/100] | Loss: 5.335434 | Recon Loss: 1.019488 | KL Loss: 0.004316
# Epoch [30/100] | Loss: 17.762026 | Recon Loss: 1.014844 | KL Loss: 0.016747
# Epoch [31/100] | Loss: 3.541101 | Recon Loss: 1.005755 | KL Loss: 0.002535
# Epoch [32/100] | Loss: 2.277799 | Recon Loss: 1.001882 | KL Loss: 0.001276
# Epoch [33/100] | Loss: 8.636322 | Recon Loss: 0.999504 | KL Loss: 0.007637
# Epoch [34/100] | Loss: 2.198656 | Recon Loss: 0.994018 | KL Loss: 0.001205
# Epoch [35/100] | Loss: 2.124084 | Recon Loss: 0.989128 | KL Loss: 0.001135
# Epoch [36/100] | Loss: 10.672119 | Recon Loss: 0.988000 | KL Loss: 0.009684
# Epoch [37/100] | Loss: 1.980100 | Recon Loss: 0.982153 | KL Loss: 0.000998
# Epoch [38/100] | Loss: 1.989504 | Recon Loss: 0.977691 | KL Loss: 0.001012
# Epoch [39/100] | Loss: 11.214887 | Recon Loss: 0.976815 | KL Loss: 0.010238
# Epoch [40/100] | Loss: 1.811723 | Recon Loss: 0.970832 | KL Loss: 0.000841
# Epoch [41/100] | Loss: 1.790867 | Recon Loss: 0.968639 | KL Loss: 0.000822
# Epoch [42/100] | Loss: 8.107783 | Recon Loss: 0.967733 | KL Loss: 0.007140
# Epoch [43/100] | Loss: 1.735136 | Recon Loss: 0.962822 | KL Loss: 0.000772
# Epoch [44/100] | Loss: 1.676695 | Recon Loss: 0.960239 | KL Loss: 0.000716
# Epoch [45/100] | Loss: 4.657978 | Recon Loss: 0.958086 | KL Loss: 0.003700
# Epoch [46/100] | Loss: 1.600457 | Recon Loss: 0.954596 | KL Loss: 0.000646
# Epoch [47/100] | Loss: 1.713097 | Recon Loss: 0.953323 | KL Loss: 0.000760
# Epoch [48/100] | Loss: 4.680998 | Recon Loss: 0.949798 | KL Loss: 0.003731
# Epoch [49/100] | Loss: 2.091044 | Recon Loss: 0.947742 | KL Loss: 0.001143
# Epoch [50/100] | Loss: 2.306678 | Recon Loss: 0.945941 | KL Loss: 0.001361
# Epoch [51/100] | Loss: 6.313226 | Recon Loss: 0.944441 | KL Loss: 0.005369
# Epoch [52/100] | Loss: 2.238150 | Recon Loss: 0.940759 | KL Loss: 0.001297
# Epoch [53/100] | Loss: 1.436427 | Recon Loss: 0.938464 | KL Loss: 0.000498
# Epoch [54/100] | Loss: 3.891506 | Recon Loss: 0.938367 | KL Loss: 0.002953
# Epoch [55/100] | Loss: 1.761301 | Recon Loss: 0.934822 | KL Loss: 0.000826
# Epoch [56/100] | Loss: 1.365970 | Recon Loss: 0.933148 | KL Loss: 0.000433
# Epoch [57/100] | Loss: 3.197969 | Recon Loss: 0.933352 | KL Loss: 0.002265
# Epoch [58/100] | Loss: 1.332031 | Recon Loss: 0.930001 | KL Loss: 0.000402
# Epoch [59/100] | Loss: 1.375427 | Recon Loss: 0.929502 | KL Loss: 0.000446
# Epoch [60/100] | Loss: 3.456936 | Recon Loss: 0.927794 | KL Loss: 0.002529
# Epoch [61/100] | Loss: 1.291450 | Recon Loss: 0.926123 | KL Loss: 0.000365
# Epoch [62/100] | Loss: 1.277541 | Recon Loss: 0.923865 | KL Loss: 0.000354
# Epoch [63/100] | Loss: 3.293301 | Recon Loss: 0.923458 | KL Loss: 0.002370
# Epoch [64/100] | Loss: 1.239016 | Recon Loss: 0.921422 | KL Loss: 0.000318
# Epoch [65/100] | Loss: 1.244213 | Recon Loss: 0.920324 | KL Loss: 0.000324
# Epoch [66/100] | Loss: 2.326340 | Recon Loss: 0.919006 | KL Loss: 0.001407
# Epoch [67/100] | Loss: 1.230875 | Recon Loss: 0.918198 | KL Loss: 0.000313
# Epoch [68/100] | Loss: 1.219778 | Recon Loss: 0.916150 | KL Loss: 0.000304
# Epoch [69/100] | Loss: 2.380170 | Recon Loss: 0.916430 | KL Loss: 0.001464
# Epoch [70/100] | Loss: 1.292901 | Recon Loss: 0.914113 | KL Loss: 0.000379
# Epoch [71/100] | Loss: 1.203662 | Recon Loss: 0.912981 | KL Loss: 0.000291
# Epoch [72/100] | Loss: 1.981795 | Recon Loss: 0.913249 | KL Loss: 0.001069
# Epoch [73/100] | Loss: 1.155899 | Recon Loss: 0.911983 | KL Loss: 0.000244
# Epoch [74/100] | Loss: 1.624063 | Recon Loss: 0.910353 | KL Loss: 0.000714
# Epoch [75/100] | Loss: 2.318133 | Recon Loss: 0.909593 | KL Loss: 0.001409
# Epoch [76/100] | Loss: 1.140304 | Recon Loss: 0.908011 | KL Loss: 0.000232
# Epoch [77/100] | Loss: 1.119360 | Recon Loss: 0.907488 | KL Loss: 0.000212
# Epoch [78/100] | Loss: 1.545956 | Recon Loss: 0.907692 | KL Loss: 0.000638
# Epoch [79/100] | Loss: 1.103799 | Recon Loss: 0.906257 | KL Loss: 0.000198
# Epoch [80/100] | Loss: 1.109160 | Recon Loss: 0.905479 | KL Loss: 0.000204
# Epoch [81/100] | Loss: 1.850408 | Recon Loss: 0.905296 | KL Loss: 0.000945
# Epoch [82/100] | Loss: 1.079024 | Recon Loss: 0.903856 | KL Loss: 0.000175
# Epoch [83/100] | Loss: 1.072790 | Recon Loss: 0.902849 | KL Loss: 0.000170
# Epoch [84/100] | Loss: 1.495122 | Recon Loss: 0.902329 | KL Loss: 0.000593
# Epoch [85/100] | Loss: 1.097975 | Recon Loss: 0.901780 | KL Loss: 0.000196
# Epoch [86/100] | Loss: 1.075975 | Recon Loss: 0.900843 | KL Loss: 0.000175
# Epoch [87/100] | Loss: 1.471418 | Recon Loss: 0.900018 | KL Loss: 0.000571
# Epoch [88/100] | Loss: 1.052106 | Recon Loss: 0.899630 | KL Loss: 0.000152
# Epoch [89/100] | Loss: 1.064686 | Recon Loss: 0.898895 | KL Loss: 0.000166
# Epoch [90/100] | Loss: 1.517516 | Recon Loss: 0.898709 | KL Loss: 0.000619
# Epoch [91/100] | Loss: 1.038554 | Recon Loss: 0.897862 | KL Loss: 0.000141
# Epoch [92/100] | Loss: 1.025863 | Recon Loss: 0.897262 | KL Loss: 0.000129
# Epoch [93/100] | Loss: 1.223643 | Recon Loss: 0.897629 | KL Loss: 0.000326
# Epoch [94/100] | Loss: 1.017782 | Recon Loss: 0.896561 | KL Loss: 0.000121
# Epoch [95/100] | Loss: 1.033826 | Recon Loss: 0.895961 | KL Loss: 0.000138
# Epoch [96/100] | Loss: 1.270039 | Recon Loss: 0.895991 | KL Loss: 0.000374
# Epoch [97/100] | Loss: 1.010753 | Recon Loss: 0.894650 | KL Loss: 0.000116
# Epoch [98/100] | Loss: 1.020079 | Recon Loss: 0.894739 | KL Loss: 0.000125
# Epoch [99/100] | Loss: 1.136910 | Recon Loss: 0.894807 | KL Loss: 0.000242
# Epoch [100/100] | Loss: 1.007958 | Recon Loss: 0.893309 | KL Loss: 0.000115

# %%
path = f"E:/GNN/experiments/trained_models/HVAE_MNIST_{scalefactor}x_prediction_mse.pth"

torch.save(model.state_dict(), path)

# %%
model.load_state_dict(torch.load(path))
# Out:
# <All keys matched successfully>

# %%
plt.plot(loss_list[1:], label='Total Loss')
plt.plot(recon_loss_list[1:], label='Reconstruction Loss')
plt.plot([l * kl_weight for l in kl_loss_list][1:], label='KL Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot()
# Out:
# []

# %%
HR, LR = test_dataset.get_samples(1000)
SR = model.sample(LR)

# %%
def show_image(x, low_res, superres, n):

    fig, axs = plt.subplots(3, n, figsize=(20, 6))
    for i in range(n):
        #figure description above every row in the middle
        if i == 0:
            axs[0, i].set_title('Original')
            axs[1, i].set_title('Low Resolution')
            axs[2, i].set_title('Super Resolution')

        axs[0, i].imshow(x[i].permute(1, 2, 0).detach().cpu().numpy(),)
        axs[0, i].axis('off')

        axs[1, i].imshow(low_res[i].permute(1, 2, 0).detach().cpu().numpy())
        axs[1, i].axis('off')

        axs[2, i].imshow(superres[i].permute(1, 2, 0).detach().cpu().numpy())
        axs[2, i].axis('off')

# %%
show_image(HR, LR, SR, 10)

# %%
n_samp = 3

for i in range(n_samp):
    reference = HR[i]
    reference = reference.repeat(batch_size, 1, 1, 1)
    reference_inp = LR[i].unsqueeze(0).repeat(batch_size, 1, 1, 1)
    
    samples = model.sample(reference_inp).detach().cpu()

    show_image(reference, reference_inp, samples, 10)

# %%
psnr_val, ssim_val, lpips_val, brisque_val, psnr_consistency_val, mse_diversity_val, lpips_diversity_val = validation_scores(model, HR, LR)
print("PSNR:", psnr_val)
print("SSIM:", ssim_val)
print("LPIPS:", lpips_val)
print("BRISQUE:", brisque_val)
print("PSNR Consistency:", psnr_consistency_val)
print("MSE Diversity:", mse_diversity_val)
print("LPIPS Diversity:", lpips_diversity_val)
# Out:
# c:\UniProgramme\anaconda3\envs\isl_segmentation\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# c:\UniProgramme\anaconda3\envs\isl_segmentation\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# PSNR: 21.460954666137695
# SSIM: 0.8443267941474915
# LPIPS: 0.07689549773931503
# BRISQUE: 68.32595825195312
# PSNR Consistency: 30.51059341430664
# MSE Diversity: 3.550961469400704e-05
# LPIPS Diversity: 0.0007771399330067652

# %%
import torch
from torchinfo import summary
import torch.optim as optim
from torch.nn import MSELoss
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader


from utils.metrics import validation_scores
from models.prediction.AE import AE
from utils.datasets import CIFAR_SR


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
num_epochs = 100
batch_size = 512
scalefactor = 2
latent_dims = [64]
channels = [32, 64, 128, 256]
in_channels = 3
base_width = 16
model = AE(in_channels=in_channels,
                          latent_dims=latent_dims,
                          channels=channels,
                          base_width=base_width
                          ).to(device)
print(model.sample(torch.randn(1, in_channels, base_width, base_width).to(device)).shape)
summary(model, input_size=(1, in_channels, base_width, base_width))
# Out:
# torch.Size([1, 3, 32, 32])
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# AE                                       [1, 3, 32, 32]            --
# ├─AELREncoder: 1-1                       [1, 64]                   --
# │    └─Conv2d: 2-1                       [1, 32, 16, 16]           128
# │    └─Conv2d: 2-2                       [1, 64, 8, 8]             32,832
# │    └─Conv2d: 2-3                       [1, 128, 4, 4]            131,200
# │    └─Linear: 2-4                       [1, 64]                   131,136
# ├─AEDecoder: 1-2                         [1, 3, 32, 32]            --
# │    └─Linear: 2-5                       [1, 4096]                 266,240
# │    └─ConvTranspose2d: 2-6              [1, 128, 8, 8]            524,416
# │    └─ConvTranspose2d: 2-7              [1, 64, 16, 16]           131,136
# │    └─ConvTranspose2d: 2-8              [1, 32, 32, 32]           32,800
# │    └─Conv2d: 2-9                       [1, 3, 32, 32]            99
# ==========================================================================================
# Total params: 1,249,987
# Trainable params: 1,249,987
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 105.45
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.63
# Params size (MB): 5.00
# Estimated Total Size (MB): 5.63
# ==========================================================================================

# %%
train_dataset = CIFAR_SR(scale_factor=scalefactor, split='train')
test_dataset = CIFAR_SR(scale_factor=scalefactor, split='test')

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
num_train_data = len(train_dataset)
print(f"Dataset Loaded: {len(train_dataset)} training samples, {len(test_dataset)} validation samples")
# Out:
# Dataset Loaded: 50000 training samples, 10000 validation samples

# %%
# Adam opt
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = MSELoss()
# Learning Rate Scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.9)

# %%
for epoch in range(num_epochs):
    model.train()
    total_loss = 0


    for HR, LR in train_loader:

        optimizer.zero_grad()

        recon_imgs = model(LR)

        loss = criterion(recon_imgs, HR)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    scheduler.step()

    print(f"Epoch [{epoch+1}/{num_epochs}] | Loss: {total_loss:.2f}")
    model.loss.append(total_loss)
# Out:
# Epoch [1/100] | Loss: 3.55
# Epoch [2/100] | Loss: 1.80
# Epoch [3/100] | Loss: 1.26
# Epoch [4/100] | Loss: 1.04
# Epoch [5/100] | Loss: 0.95
# Epoch [6/100] | Loss: 0.87
# Epoch [7/100] | Loss: 0.82
# Epoch [8/100] | Loss: 0.80
# Epoch [9/100] | Loss: 0.78
# Epoch [10/100] | Loss: 0.77
# Epoch [11/100] | Loss: 0.77
# Epoch [12/100] | Loss: 0.76
# Epoch [13/100] | Loss: 0.76
# Epoch [14/100] | Loss: 0.75
# Epoch [15/100] | Loss: 0.75
# Epoch [16/100] | Loss: 0.75
# Epoch [17/100] | Loss: 0.74
# Epoch [18/100] | Loss: 0.74
# Epoch [19/100] | Loss: 0.74
# Epoch [20/100] | Loss: 0.74
# Epoch [21/100] | Loss: 0.73
# Epoch [22/100] | Loss: 0.73
# Epoch [23/100] | Loss: 0.73
# Epoch [24/100] | Loss: 0.73
# Epoch [25/100] | Loss: 0.72
# Epoch [26/100] | Loss: 0.72
# Epoch [27/100] | Loss: 0.72
# Epoch [28/100] | Loss: 0.72
# Epoch [29/100] | Loss: 0.72
# Epoch [30/100] | Loss: 0.72
# Epoch [31/100] | Loss: 0.71
# Epoch [32/100] | Loss: 0.71
# Epoch [33/100] | Loss: 0.71
# Epoch [34/100] | Loss: 0.71
# Epoch [35/100] | Loss: 0.71
# Epoch [36/100] | Loss: 0.71

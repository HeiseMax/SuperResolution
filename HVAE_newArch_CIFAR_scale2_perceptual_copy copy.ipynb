# %%
import torch
import numpy as np
import os
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
import time
import random
import matplotlib.pyplot as plt

# %%
# Utility Functions
def gaussian_kl(mu1, logsigma1, mu2, logsigma2):
    """Computes the KL divergence between two diagonal Gaussians."""
    return -0.5 + logsigma2 - logsigma1 + 0.5 * (logsigma1.exp() ** 2 + (mu1 - mu2) ** 2) / (logsigma2.exp() ** 2)


def sample_latent(mu, logvar, prev_z=None):
    """Samples a latent variable conditioned on the previous latent."""
    eps = torch.empty_like(mu).normal_(0., 1.)
    z = torch.exp(logvar) * eps + mu
    if prev_z is not None:
        z = z + prev_z
    return z


def get_conv(in_dim, out_dim, kernel_size=3, stride=1, padding=1):
    """Creates a 2D convolutional layer."""
    c = nn.Conv2d(in_dim, out_dim, kernel_size, stride, padding)
    nn.init.kaiming_normal_(c.weight)
    return c


def get_3x3(in_dim, out_dim):
    """Creates a 3x3 convolutional layer."""
    return get_conv(in_dim, out_dim, 3, 1, 1)


# Encoder Module
class HierarchicalLREncoder(nn.Module):
    def __init__(self, in_channels=3, base_width=32, latent_dims=None):
        super().__init__()
        self.in_conv = nn.Conv2d(3, 32, 1, 1, 0)  # 16x16
        self.down1 = nn.Conv2d(32, 64, 4, stride=2, padding=1)  # 8x8

        self.fc1 = nn.Linear(64 * 8 * 8, 64)
        self.fc2 = nn.Linear(32 * 16 * 16, 128)

    def forward(self, x):
        x0 = self.in_conv(x)  # Expected: (batch, 32, 16, 16)
        x1 = self.down1(x0)  # Expected: (batch, 64, 8, 8)

        c1 = self.fc1(x1.view(x1.size(0), -1))
        c2 = self.fc2(x0.view(x0.size(0), -1))

        return [c1, c2]

class HierarchicalEncoder(nn.Module):
    def __init__(self, in_channels=3, base_width=32, latent_dims=None):
        super().__init__()
        self.in_conv = nn.Conv2d(3, 32, 1, 1, 0)  # 32x32
        self.down1 = nn.Conv2d(32, 64, 4, stride=2, padding=1)  # 16x16
        self.down2 = nn.Conv2d(64, 128, 4, stride=2, padding=1)  # 8x8

        self.fc_mu1 = nn.Linear(128 * 8 * 8, 64)
        self.fc_logvar1 = nn.Linear(128 * 8 * 8, 64)

        self.fc_mu2 = nn.Linear(64 * 16 * 16, 128)
        self.fc_logvar2 = nn.Linear(64 * 16 * 16, 128)

        self.fc_mu3 = nn.Linear(32 * 32 * 32, 256)
        self.fc_logvar3 = nn.Linear(32 * 32 * 32, 256)

    def forward(self, x):
        x0 = self.in_conv(x)  # Expected: (batch, 32, 32, 32)
        x1 = self.down1(x0)  # Expected: (batch, 32, 16, 16)
        x2 = self.down2(x1)  # Expected: (batch, 64, 8, 8)

        mu1, logvar1 = self.fc_mu1(x2.view(x2.size(0), -1)), self.fc_logvar1(x2.view(x2.size(0), -1))
        mu2, logvar2 = self.fc_mu2(x1.view(x1.size(0), -1)), self.fc_logvar2(x1.view(x1.size(0), -1))
        mu3, logvar3 = self.fc_mu3(x0.view(x0.size(0), -1)), self.fc_logvar3(x0.view(x0.size(0), -1))

        return [(mu1, logvar1), (mu2, logvar2), (mu3, logvar3)]


# Decoder Module
class HierarchicalDecoder(nn.Module):
    def __init__(self, latent_dims=[32, 64, 128, 256], base_width=32, out_channels=3):
        super().__init__()
        self.fc1 = nn.Linear(64, 128 * 8 * 8)
        self.fc2 = nn.Linear(128, 64 * 16 * 16)
        self.fc3 = nn.Linear(256, 32 * 32 * 32)

        self.fc_cond1 = nn.Linear(64, 128 * 8 * 8)
        self.fc_cond2 = nn.Linear(128, 64 * 16 * 16)

        self.deconv1 = nn.ConvTranspose2d(128*2, 64, 4, stride=2, padding=1)  # 16x16
        self.deconv2 = nn.ConvTranspose2d(64*2, 32, 4, stride=2, padding=1)  # 32x32

        self.out_conv = nn.Conv2d(32, 3, 1, 1, 0)

    def forward(self, z_hierarchical, condition):
        z1, z2, z3 = z_hierarchical
        c1, c2 = condition

        z1 = self.fc1(z1).view(-1, 128, 8, 8)
        z2 = self.fc2(z2).view(-1, 64, 16, 16)
        z3 = self.fc3(z3).view(-1, 32, 32, 32)

        c1 = self.fc_cond1(c1).view(-1, 128, 8, 8)
        c2 = self.fc_cond2(c2).view(-1, 64, 16, 16)

        x1 = torch.cat([z1, c1], dim=1)
        x2 = self.deconv1(x1)  # Expected: (batch, 64, 16, 16)
        x2 = nn.ReLU()(x2)
        x2 = x2 + z2
        x2 = torch.cat([x2, c2], dim=1)
        x3 = self.deconv2(x2)  # Expected: (batch, 32, 32, 32)
        x3 = nn.ReLU()(x3)
        x3 = x3 + z3
        x3 = self.out_conv(x3)
        return torch.sigmoid(x3)


# Hierarchical VDVAE Model
class HierarchicalVDVAE(nn.Module):
    def __init__(self, in_channels=3, base_width=32, latent_dims = [64, 128, 256]):
        super().__init__()
        self.encoder = HierarchicalEncoder(in_channels, base_width, latent_dims)
        self.lr_encoder = HierarchicalLREncoder(in_channels, base_width, latent_dims)
        self.decoder = HierarchicalDecoder(latent_dims, base_width, in_channels)

        # Add Linear layers to project latent dimensions before conditioning
        # self.project_z1 = nn.Linear(latent_dims[0], latent_dims[1])  # Projects 32 → 64
        # self.project_z2 = nn.Linear(latent_dims[1], latent_dims[2])  # Projects 64 → 128

    def forward(self, x, x_lr):
        latents = self.encoder(x)
        condition = self.lr_encoder(x_lr)

        # Hierarchical latent sampling with projection
        z1 = sample_latent(latents[0][0], latents[0][1])
        z2 = sample_latent(latents[1][0], latents[1][1])
        z3 = sample_latent(latents[2][0], latents[2][1])

        sampled_latents = [z1, z2, z3]
        recon_x = self.decoder(sampled_latents, condition)
        return recon_x, latents

    def sample(self, x_lr):
        num_samples = x_lr.size(0)
        z1 = torch.randn(num_samples, 64).to(next(self.parameters()).device)
        z2 = torch.randn(num_samples, 128).to(next(self.parameters()).device)
        z3 = torch.randn(num_samples, 256).to(next(self.parameters()).device)
        sampled_latents = [z1, z2, z3]
        condition = self.lr_encoder(x_lr)
        recon_x = self.decoder(sampled_latents, condition)
        return recon_x

# %%
# device
cuda = True
DEVICE = torch.device("cuda" if cuda and torch.cuda.is_available() else "cpu")
print(DEVICE)

# data
scale_factor = 2
image_size = 32
num_channels = 3

# model
latent_dims = [64, 128, 256, 512]
#latent_dims = [256, 512,1024]
#latent_dims = [128, 256, 512]
#latent_dims = [32, 64, 128]

# training
batch_size = 256
num_epochs = 250
save_interval = num_epochs
validation_interval = 25

#checkpointing
checkpoint_dir = "./checkpoints/"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
# Out:
# cuda

# %%
# device
cuda = True
DEVICE = torch.device("cuda" if cuda and torch.cuda.is_available() else "cpu")
print(DEVICE)

# data
scale_factor = 2
image_size = 32
num_channels = 3

# model
latent_dims = [64, 128, 256, 512]
#latent_dims = [256, 512,1024]
#latent_dims = [128, 256, 512]
#latent_dims = [32, 64, 128]

# training
batch_size = 256
num_epochs = 250
save_interval = num_epochs
validation_interval = 25

#checkpointing
checkpoint_dir = "./checkpoints/"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
# Out:
# cuda

# %%
from datasets import CIFAR_SR

train_dataset = CIFAR_SR(scale_factor=scale_factor, split="train", download=True, device=DEVICE)
val_dataset = CIFAR_SR(scale_factor=scale_factor, split="test", download=True, device=DEVICE)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model = HierarchicalVDVAE(in_channels=num_channels, latent_dims=latent_dims).to(DEVICE)

optimizer = optim.Adam(model.parameters(), lr=1e-4)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.9)

# %%
from torchvision import models

class PerceptualLoss(nn.Module):
    def __init__(self):
        super().__init__()
        vgg = models.vgg16(pretrained=True).features[:16]  # Use first layers
        for param in vgg.parameters():
            param.requires_grad = False  # Freeze VGG weights
        self.vgg = vgg

    def forward(self, pred, target):
        pred_features = self.vgg(pred)
        target_features = self.vgg(target)
        return F.mse_loss(pred_features, target_features, reduction="mean")  # Feature-level loss

perceptual_criterion = PerceptualLoss().to(DEVICE)
# Out:
# c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def loss_function(recon_x, x, latents, perceptual_criterion, alpha=1.0, beta=1.0, gamma=1.0):
    # Reconstruction loss
    recon_loss = F.mse_loss(recon_x, x, reduction='mean')

    # KL divergence
    kl_loss = 0
    for mu, logvar in latents:
        kl_loss += torch.mean(gaussian_kl(mu, logvar, torch.zeros_like(mu), torch.zeros_like(logvar)))
    kl_loss /= len(latents)

    # Perceptual loss
    perceptual_loss = torch.Tensor([0]).to(DEVICE) #perceptual_criterion(recon_x, x)

    # total loss
    total_loss = alpha * recon_loss + beta * kl_loss# + gamma * perceptual_loss
    return total_loss, recon_loss, kl_loss, perceptual_loss

# %%
loss_history = {"total_loss": [], "recon_loss": [], "kl_loss": [], "perceptual_loss": []}
val_loss_history = {"total_loss": [], "recon_loss": [], "kl_loss": [], "perceptual_loss": []}

# %%
total_training_start = time.time()  # Start time for overall training
alpha = 1.0
beta = 10.0
gamma = 0.0

for epoch in range(num_epochs):
    epoch_start = time.time()  # Start time for the epoch

    model.train()
    total_loss, total_recon_loss, total_kl_loss, total_perceptual_loss = [], [], [], []

    # Training
    for hr_imgs, lr_imgs in train_loader:

        optimizer.zero_grad()
        recon_imgs, latents = model(hr_imgs, lr_imgs)

        # Loss computation
        loss, recon_loss, kl_loss, perceptual_loss = loss_function(recon_imgs, hr_imgs, latents, perceptual_criterion, alpha=alpha, beta=beta, gamma=gamma)

        loss.backward()
        optimizer.step()

        total_loss.append(loss.item())
        total_recon_loss.append(recon_loss.item())
        total_kl_loss.append(kl_loss.item())
        total_perceptual_loss.append(perceptual_loss.item())

    scheduler.step()  # Adjust learning rate

    epoch_end = time.time()  # End time for the epoch
    epoch_time = epoch_end - epoch_start

    loss_history["total_loss"].append(np.mean(total_loss))
    loss_history["recon_loss"].append(np.mean(total_recon_loss))
    loss_history["kl_loss"].append(np.mean(total_kl_loss))
    loss_history["perceptual_loss"].append(np.mean(total_perceptual_loss))

    print(f"Epoch [{epoch+1}/{num_epochs}] | Time: {epoch_time:.2f}s | TotalLoss: {loss_history['total_loss'][-1]:.6f} | Perceptual: {loss_history['perceptual_loss'][-1]:.6f} | Recon: {loss_history['recon_loss'][-1]:.6f} | KL: {loss_history['kl_loss'][-1]:.6f}")

    # Validation
    if (epoch + 1) % validation_interval == 0:
        model.eval()
        with torch.no_grad():
            total_val_loss, total_val_recon_loss, total_val_kl_loss, total_val_perceptual_loss = [], [], [], []
            for hr_imgs, lr_imgs in val_loader:
                recon_imgs, latents = model(hr_imgs, lr_imgs)

                # Loss computation
                val_total_loss, val_recon_loss, val_kl_loss, val_perceptual_loss = loss_function(recon_imgs, hr_imgs, latents, perceptual_criterion, alpha=alpha, beta=beta, gamma=gamma)

                total_val_loss.append(val_total_loss.item())
                total_val_recon_loss.append(val_recon_loss.item())
                total_val_kl_loss.append(val_kl_loss.item())
                total_val_perceptual_loss.append(val_perceptual_loss.item())

            val_loss_history["total_loss"].append(np.mean(total_val_loss))
            val_loss_history["recon_loss"].append(np.mean(total_val_recon_loss))
            val_loss_history["kl_loss"].append(np.mean(total_val_kl_loss))
            val_loss_history["perceptual_loss"].append(np.mean(total_val_perceptual_loss))

            print(f"Validation | TotalLoss: {val_loss_history['total_loss'][-1]:.6f} | Perceptual: {val_loss_history['perceptual_loss'][-1]:.6f} | Recon: {val_loss_history['recon_loss'][-1]:.6f} | KL: {val_loss_history['kl_loss'][-1]:.6f}")

    # Save checkpoint
    if (epoch + 1) % save_interval == 0:
        checkpoint_path = os.path.join(checkpoint_dir, f"vdvae2_epoch_{epoch+1}.pth")
        torch.save({
            'epoch': epoch + 1,
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict()
        }, checkpoint_path)
        print(f"Checkpoint saved: {checkpoint_path}")

total_training_end = time.time()  # End time for overall training
total_training_time = total_training_end - total_training_start
print(f"Total Training Time: {total_training_time:.2f}s")
# Out:
# Epoch [1/250] | Time: 49.02s | TotalLoss: 0.175033 | Perceptual: 0.000000 | Recon: 0.040559 | KL: 0.013447
# Epoch [2/250] | Time: 48.63s | TotalLoss: 0.020902 | Perceptual: 0.000000 | Recon: 0.018252 | KL: 0.000265
# Epoch [3/250] | Time: 49.03s | TotalLoss: 0.014913 | Perceptual: 0.000000 | Recon: 0.013207 | KL: 0.000171
# Epoch [4/250] | Time: 48.71s | TotalLoss: 0.012189 | Perceptual: 0.000000 | Recon: 0.010933 | KL: 0.000126
# Epoch [5/250] | Time: 48.83s | TotalLoss: 0.010601 | Perceptual: 0.000000 | Recon: 0.009606 | KL: 0.000100
# Epoch [6/250] | Time: 49.11s | TotalLoss: 0.009436 | Perceptual: 0.000000 | Recon: 0.008512 | KL: 0.000092
# Epoch [7/250] | Time: 48.42s | TotalLoss: 0.009268 | Perceptual: 0.000000 | Recon: 0.007784 | KL: 0.000148
# Epoch [8/250] | Time: 49.23s | TotalLoss: 0.009242 | Perceptual: 0.000000 | Recon: 0.007324 | KL: 0.000192
# Epoch [9/250] | Time: 48.78s | TotalLoss: 0.009171 | Perceptual: 0.000000 | Recon: 0.006943 | KL: 0.000223
# Epoch [10/250] | Time: 49.02s | TotalLoss: 0.009150 | Perceptual: 0.000000 | Recon: 0.006624 | KL: 0.000253
# Epoch [11/250] | Time: 49.08s | TotalLoss: 0.007034 | Perceptual: 0.000000 | Recon: 0.006379 | KL: 0.000065
# Epoch [12/250] | Time: 50.05s | TotalLoss: 0.008329 | Perceptual: 0.000000 | Recon: 0.006189 | KL: 0.000214
# Epoch [13/250] | Time: 48.54s | TotalLoss: 0.008291 | Perceptual: 0.000000 | Recon: 0.006026 | KL: 0.000226
# Epoch [14/250] | Time: 48.88s | TotalLoss: 0.008238 | Perceptual: 0.000000 | Recon: 0.005883 | KL: 0.000236
# Epoch [15/250] | Time: 48.34s | TotalLoss: 0.008076 | Perceptual: 0.000000 | Recon: 0.005757 | KL: 0.000232
# Epoch [16/250] | Time: 49.60s | TotalLoss: 0.007871 | Perceptual: 0.000000 | Recon: 0.005653 | KL: 0.000222
# Epoch [17/250] | Time: 48.70s | TotalLoss: 0.007996 | Perceptual: 0.000000 | Recon: 0.005556 | KL: 0.000244
# Epoch [18/250] | Time: 47.49s | TotalLoss: 0.007883 | Perceptual: 0.000000 | Recon: 0.005477 | KL: 0.000241
# Epoch [19/250] | Time: 47.15s | TotalLoss: 0.007954 | Perceptual: 0.000000 | Recon: 0.005405 | KL: 0.000255
# Epoch [20/250] | Time: 45.99s | TotalLoss: 0.007728 | Perceptual: 0.000000 | Recon: 0.005340 | KL: 0.000239
# Epoch [21/250] | Time: 47.51s | TotalLoss: 0.005584 | Perceptual: 0.000000 | Recon: 0.005287 | KL: 0.000030
# Epoch [22/250] | Time: 94.26s | TotalLoss: 0.007017 | Perceptual: 0.000000 | Recon: 0.005246 | KL: 0.000177
# Epoch [23/250] | Time: 104.22s | TotalLoss: 0.007157 | Perceptual: 0.000000 | Recon: 0.005215 | KL: 0.000194
# Epoch [24/250] | Time: 99.98s | TotalLoss: 0.007069 | Perceptual: 0.000000 | Recon: 0.005191 | KL: 0.000188
# Epoch [25/250] | Time: 100.44s | TotalLoss: 0.007019 | Perceptual: 0.000000 | Recon: 0.005171 | KL: 0.000185
# Validation | TotalLoss: 0.007777 | Perceptual: 0.000000 | Recon: 0.005178 | KL: 0.000260
# Epoch [26/250] | Time: 99.58s | TotalLoss: 0.006908 | Perceptual: 0.000000 | Recon: 0.005153 | KL: 0.000176
# Epoch [27/250] | Time: 100.53s | TotalLoss: 0.006818 | Perceptual: 0.000000 | Recon: 0.005136 | KL: 0.000168
# Epoch [28/250] | Time: 99.66s | TotalLoss: 0.006716 | Perceptual: 0.000000 | Recon: 0.005124 | KL: 0.000159
# Epoch [29/250] | Time: 100.88s | TotalLoss: 0.006636 | Perceptual: 0.000000 | Recon: 0.005110 | KL: 0.000153
# Epoch [30/250] | Time: 100.94s | TotalLoss: 0.006607 | Perceptual: 0.000000 | Recon: 0.005099 | KL: 0.000151
# Epoch [31/250] | Time: 96.02s | TotalLoss: 0.005265 | Perceptual: 0.000000 | Recon: 0.005086 | KL: 0.000018
# Epoch [32/250] | Time: 99.20s | TotalLoss: 0.006103 | Perceptual: 0.000000 | Recon: 0.005076 | KL: 0.000103
# Epoch [33/250] | Time: 93.21s | TotalLoss: 0.006227 | Perceptual: 0.000000 | Recon: 0.005069 | KL: 0.000116
# Epoch [34/250] | Time: 95.58s | TotalLoss: 0.006161 | Perceptual: 0.000000 | Recon: 0.005060 | KL: 0.000110
# Epoch [35/250] | Time: 92.45s | TotalLoss: 0.006140 | Perceptual: 0.000000 | Recon: 0.005053 | KL: 0.000109
# Epoch [36/250] | Time: 93.72s | TotalLoss: 0.006022 | Perceptual: 0.000000 | Recon: 0.005043 | KL: 0.000098
# Epoch [37/250] | Time: 90.67s | TotalLoss: 0.005994 | Perceptual: 0.000000 | Recon: 0.005034 | KL: 0.000096
# Epoch [38/250] | Time: 90.17s | TotalLoss: 0.005969 | Perceptual: 0.000000 | Recon: 0.005022 | KL: 0.000095
# Epoch [39/250] | Time: 89.87s | TotalLoss: 0.005930 | Perceptual: 0.000000 | Recon: 0.005007 | KL: 0.000092
# Epoch [40/250] | Time: 93.04s | TotalLoss: 0.005768 | Perceptual: 0.000000 | Recon: 0.004985 | KL: 0.000078
# Epoch [41/250] | Time: 92.10s | TotalLoss: 0.005057 | Perceptual: 0.000000 | Recon: 0.004959 | KL: 0.000010
# Epoch [42/250] | Time: 92.31s | TotalLoss: 0.005504 | Perceptual: 0.000000 | Recon: 0.004931 | KL: 0.000057
# Epoch [43/250] | Time: 91.88s | TotalLoss: 0.005562 | Perceptual: 0.000000 | Recon: 0.004907 | KL: 0.000065
# Epoch [44/250] | Time: 92.46s | TotalLoss: 0.005519 | Perceptual: 0.000000 | Recon: 0.004881 | KL: 0.000064
# Epoch [45/250] | Time: 91.94s | TotalLoss: 0.005446 | Perceptual: 0.000000 | Recon: 0.004858 | KL: 0.000059
# Epoch [46/250] | Time: 92.71s | TotalLoss: 0.005402 | Perceptual: 0.000000 | Recon: 0.004842 | KL: 0.000056
# Epoch [47/250] | Time: 88.76s | TotalLoss: 0.005354 | Perceptual: 0.000000 | Recon: 0.004820 | KL: 0.000053
# Epoch [48/250] | Time: 91.99s | TotalLoss: 0.005330 | Perceptual: 0.000000 | Recon: 0.004801 | KL: 0.000053
# Epoch [49/250] | Time: 92.16s | TotalLoss: 0.005271 | Perceptual: 0.000000 | Recon: 0.004781 | KL: 0.000049
# Epoch [50/250] | Time: 92.29s | TotalLoss: 0.005232 | Perceptual: 0.000000 | Recon: 0.004761 | KL: 0.000047
# Validation | TotalLoss: 0.005122 | Perceptual: 0.000000 | Recon: 0.004776 | KL: 0.000035
# Epoch [51/250] | Time: 91.81s | TotalLoss: 0.004798 | Perceptual: 0.000000 | Recon: 0.004735 | KL: 0.000006
# Epoch [52/250] | Time: 92.78s | TotalLoss: 0.005021 | Perceptual: 0.000000 | Recon: 0.004708 | KL: 0.000031
# Epoch [53/250] | Time: 92.06s | TotalLoss: 0.005055 | Perceptual: 0.000000 | Recon: 0.004680 | KL: 0.000038
# Epoch [54/250] | Time: 91.81s | TotalLoss: 0.005025 | Perceptual: 0.000000 | Recon: 0.004658 | KL: 0.000037
# Epoch [55/250] | Time: 92.01s | TotalLoss: 0.004962 | Perceptual: 0.000000 | Recon: 0.004636 | KL: 0.000033
# Epoch [56/250] | Time: 91.67s | TotalLoss: 0.004935 | Perceptual: 0.000000 | Recon: 0.004615 | KL: 0.000032
# Epoch [57/250] | Time: 91.70s | TotalLoss: 0.004918 | Perceptual: 0.000000 | Recon: 0.004599 | KL: 0.000032
# Epoch [58/250] | Time: 91.75s | TotalLoss: 0.004883 | Perceptual: 0.000000 | Recon: 0.004583 | KL: 0.000030
# Epoch [59/250] | Time: 92.46s | TotalLoss: 0.004874 | Perceptual: 0.000000 | Recon: 0.004570 | KL: 0.000030
# Epoch [60/250] | Time: 91.74s | TotalLoss: 0.004826 | Perceptual: 0.000000 | Recon: 0.004557 | KL: 0.000027
# Epoch [61/250] | Time: 92.33s | TotalLoss: 0.004595 | Perceptual: 0.000000 | Recon: 0.004542 | KL: 0.000005
# Epoch [62/250] | Time: 92.23s | TotalLoss: 0.004705 | Perceptual: 0.000000 | Recon: 0.004532 | KL: 0.000017
# Epoch [63/250] | Time: 91.90s | TotalLoss: 0.004747 | Perceptual: 0.000000 | Recon: 0.004520 | KL: 0.000023
# Epoch [64/250] | Time: 91.94s | TotalLoss: 0.004727 | Perceptual: 0.000000 | Recon: 0.004515 | KL: 0.000021
# Epoch [65/250] | Time: 92.90s | TotalLoss: 0.004708 | Perceptual: 0.000000 | Recon: 0.004507 | KL: 0.000020
# Epoch [66/250] | Time: 92.12s | TotalLoss: 0.004711 | Perceptual: 0.000000 | Recon: 0.004500 | KL: 0.000021
# Epoch [67/250] | Time: 92.27s | TotalLoss: 0.004689 | Perceptual: 0.000000 | Recon: 0.004492 | KL: 0.000020
# Epoch [68/250] | Time: 92.15s | TotalLoss: 0.004659 | Perceptual: 0.000000 | Recon: 0.004488 | KL: 0.000017
# Epoch [69/250] | Time: 91.79s | TotalLoss: 0.004668 | Perceptual: 0.000000 | Recon: 0.004482 | KL: 0.000019
# Epoch [70/250] | Time: 92.10s | TotalLoss: 0.004651 | Perceptual: 0.000000 | Recon: 0.004474 | KL: 0.000018
# Epoch [71/250] | Time: 92.13s | TotalLoss: 0.004496 | Perceptual: 0.000000 | Recon: 0.004470 | KL: 0.000003
# Epoch [72/250] | Time: 89.27s | TotalLoss: 0.004593 | Perceptual: 0.000000 | Recon: 0.004464 | KL: 0.000013
# Epoch [73/250] | Time: 92.02s | TotalLoss: 0.004600 | Perceptual: 0.000000 | Recon: 0.004463 | KL: 0.000014
# Epoch [74/250] | Time: 91.94s | TotalLoss: 0.004594 | Perceptual: 0.000000 | Recon: 0.004457 | KL: 0.000014
# Epoch [75/250] | Time: 91.94s | TotalLoss: 0.004581 | Perceptual: 0.000000 | Recon: 0.004452 | KL: 0.000013
# Validation | TotalLoss: 0.004564 | Perceptual: 0.000000 | Recon: 0.004478 | KL: 0.000009
# Epoch [76/250] | Time: 92.06s | TotalLoss: 0.004574 | Perceptual: 0.000000 | Recon: 0.004448 | KL: 0.000013
# Epoch [77/250] | Time: 92.41s | TotalLoss: 0.004599 | Perceptual: 0.000000 | Recon: 0.004445 | KL: 0.000015
# Epoch [78/250] | Time: 92.65s | TotalLoss: 0.004536 | Perceptual: 0.000000 | Recon: 0.004441 | KL: 0.000009
# Epoch [79/250] | Time: 92.00s | TotalLoss: 0.004554 | Perceptual: 0.000000 | Recon: 0.004437 | KL: 0.000012
# Epoch [80/250] | Time: 91.75s | TotalLoss: 0.004558 | Perceptual: 0.000000 | Recon: 0.004434 | KL: 0.000012
# Epoch [81/250] | Time: 91.90s | TotalLoss: 0.004453 | Perceptual: 0.000000 | Recon: 0.004429 | KL: 0.000002
# Epoch [82/250] | Time: 92.21s | TotalLoss: 0.004487 | Perceptual: 0.000000 | Recon: 0.004423 | KL: 0.000006
# Epoch [83/250] | Time: 91.84s | TotalLoss: 0.004518 | Perceptual: 0.000000 | Recon: 0.004421 | KL: 0.000010
# Epoch [84/250] | Time: 92.04s | TotalLoss: 0.004505 | Perceptual: 0.000000 | Recon: 0.004416 | KL: 0.000009
# Epoch [85/250] | Time: 93.39s | TotalLoss: 0.004496 | Perceptual: 0.000000 | Recon: 0.004413 | KL: 0.000008
# Epoch [86/250] | Time: 92.56s | TotalLoss: 0.004496 | Perceptual: 0.000000 | Recon: 0.004409 | KL: 0.000009
# Epoch [87/250] | Time: 92.44s | TotalLoss: 0.004487 | Perceptual: 0.000000 | Recon: 0.004404 | KL: 0.000008
# Epoch [88/250] | Time: 92.12s | TotalLoss: 0.004491 | Perceptual: 0.000000 | Recon: 0.004402 | KL: 0.000009
# Epoch [89/250] | Time: 92.53s | TotalLoss: 0.004478 | Perceptual: 0.000000 | Recon: 0.004399 | KL: 0.000008
# Epoch [90/250] | Time: 92.27s | TotalLoss: 0.004463 | Perceptual: 0.000000 | Recon: 0.004394 | KL: 0.000007
# Epoch [91/250] | Time: 92.92s | TotalLoss: 0.004406 | Perceptual: 0.000000 | Recon: 0.004388 | KL: 0.000002
# Epoch [92/250] | Time: 92.30s | TotalLoss: 0.004445 | Perceptual: 0.000000 | Recon: 0.004384 | KL: 0.000006
# Epoch [93/250] | Time: 92.21s | TotalLoss: 0.004443 | Perceptual: 0.000000 | Recon: 0.004383 | KL: 0.000006
# Epoch [94/250] | Time: 92.22s | TotalLoss: 0.004436 | Perceptual: 0.000000 | Recon: 0.004378 | KL: 0.000006
# Epoch [95/250] | Time: 92.70s | TotalLoss: 0.004432 | Perceptual: 0.000000 | Recon: 0.004376 | KL: 0.000006
# Epoch [96/250] | Time: 92.41s | TotalLoss: 0.004427 | Perceptual: 0.000000 | Recon: 0.004372 | KL: 0.000006
# Epoch [97/250] | Time: 89.19s | TotalLoss: 0.004432 | Perceptual: 0.000000 | Recon: 0.004371 | KL: 0.000006
# Epoch [98/250] | Time: 92.36s | TotalLoss: 0.004413 | Perceptual: 0.000000 | Recon: 0.004369 | KL: 0.000004
# Epoch [99/250] | Time: 92.37s | TotalLoss: 0.004429 | Perceptual: 0.000000 | Recon: 0.004369 | KL: 0.000006
# Epoch [100/250] | Time: 92.44s | TotalLoss: 0.004424 | Perceptual: 0.000000 | Recon: 0.004364 | KL: 0.000006
# Validation | TotalLoss: 0.004433 | Perceptual: 0.000000 | Recon: 0.004400 | KL: 0.000003
# Epoch [101/250] | Time: 92.33s | TotalLoss: 0.004373 | Perceptual: 0.000000 | Recon: 0.004362 | KL: 0.000001
# Epoch [102/250] | Time: 92.43s | TotalLoss: 0.004391 | Perceptual: 0.000000 | Recon: 0.004359 | KL: 0.000003
# Epoch [103/250] | Time: 92.15s | TotalLoss: 0.004401 | Perceptual: 0.000000 | Recon: 0.004359 | KL: 0.000004
# Epoch [104/250] | Time: 93.07s | TotalLoss: 0.004398 | Perceptual: 0.000000 | Recon: 0.004357 | KL: 0.000004
# Epoch [105/250] | Time: 92.37s | TotalLoss: 0.004396 | Perceptual: 0.000000 | Recon: 0.004356 | KL: 0.000004
# Epoch [106/250] | Time: 92.34s | TotalLoss: 0.004398 | Perceptual: 0.000000 | Recon: 0.004354 | KL: 0.000004
# Epoch [107/250] | Time: 93.44s | TotalLoss: 0.004392 | Perceptual: 0.000000 | Recon: 0.004353 | KL: 0.000004
# Epoch [108/250] | Time: 92.14s | TotalLoss: 0.004394 | Perceptual: 0.000000 | Recon: 0.004352 | KL: 0.000004
# Epoch [109/250] | Time: 92.18s | TotalLoss: 0.004390 | Perceptual: 0.000000 | Recon: 0.004350 | KL: 0.000004
# Epoch [110/250] | Time: 92.66s | TotalLoss: 0.004387 | Perceptual: 0.000000 | Recon: 0.004350 | KL: 0.000004
# Epoch [111/250] | Time: 92.09s | TotalLoss: 0.004355 | Perceptual: 0.000000 | Recon: 0.004345 | KL: 0.000001
# Epoch [112/250] | Time: 92.12s | TotalLoss: 0.004368 | Perceptual: 0.000000 | Recon: 0.004346 | KL: 0.000002
# Epoch [113/250] | Time: 92.39s | TotalLoss: 0.004372 | Perceptual: 0.000000 | Recon: 0.004344 | KL: 0.000003
# Epoch [114/250] | Time: 92.19s | TotalLoss: 0.004381 | Perceptual: 0.000000 | Recon: 0.004344 | KL: 0.000004
# Epoch [115/250] | Time: 92.14s | TotalLoss: 0.004372 | Perceptual: 0.000000 | Recon: 0.004342 | KL: 0.000003
# Epoch [116/250] | Time: 92.08s | TotalLoss: 0.004375 | Perceptual: 0.000000 | Recon: 0.004342 | KL: 0.000003
# Epoch [117/250] | Time: 92.46s | TotalLoss: 0.004366 | Perceptual: 0.000000 | Recon: 0.004342 | KL: 0.000002
# Epoch [118/250] | Time: 92.22s | TotalLoss: 0.004368 | Perceptual: 0.000000 | Recon: 0.004340 | KL: 0.000003
# Epoch [119/250] | Time: 92.27s | TotalLoss: 0.004370 | Perceptual: 0.000000 | Recon: 0.004339 | KL: 0.000003
# Epoch [120/250] | Time: 92.40s | TotalLoss: 0.004372 | Perceptual: 0.000000 | Recon: 0.004340 | KL: 0.000003
# Epoch [121/250] | Time: 91.94s | TotalLoss: 0.004344 | Perceptual: 0.000000 | Recon: 0.004336 | KL: 0.000001
# Epoch [122/250] | Time: 92.15s | TotalLoss: 0.004350 | Perceptual: 0.000000 | Recon: 0.004335 | KL: 0.000002
# Epoch [123/250] | Time: 89.51s | TotalLoss: 0.004360 | Perceptual: 0.000000 | Recon: 0.004334 | KL: 0.000003
# Epoch [124/250] | Time: 92.11s | TotalLoss: 0.004352 | Perceptual: 0.000000 | Recon: 0.004334 | KL: 0.000002
# Epoch [125/250] | Time: 92.31s | TotalLoss: 0.004355 | Perceptual: 0.000000 | Recon: 0.004333 | KL: 0.000002
# Validation | TotalLoss: 0.004425 | Perceptual: 0.000000 | Recon: 0.004370 | KL: 0.000006
# Epoch [126/250] | Time: 92.30s | TotalLoss: 0.004355 | Perceptual: 0.000000 | Recon: 0.004333 | KL: 0.000002
# Epoch [127/250] | Time: 92.70s | TotalLoss: 0.004355 | Perceptual: 0.000000 | Recon: 0.004332 | KL: 0.000002
# Epoch [128/250] | Time: 92.21s | TotalLoss: 0.004356 | Perceptual: 0.000000 | Recon: 0.004332 | KL: 0.000002
# Epoch [129/250] | Time: 92.27s | TotalLoss: 0.004347 | Perceptual: 0.000000 | Recon: 0.004329 | KL: 0.000002
# Epoch [130/250] | Time: 92.96s | TotalLoss: 0.004351 | Perceptual: 0.000000 | Recon: 0.004330 | KL: 0.000002
# Epoch [131/250] | Time: 92.39s | TotalLoss: 0.004336 | Perceptual: 0.000000 | Recon: 0.004328 | KL: 0.000001
# Epoch [132/250] | Time: 92.28s | TotalLoss: 0.004340 | Perceptual: 0.000000 | Recon: 0.004327 | KL: 0.000001
# Epoch [133/250] | Time: 92.37s | TotalLoss: 0.004342 | Perceptual: 0.000000 | Recon: 0.004325 | KL: 0.000002
# Epoch [134/250] | Time: 92.33s | TotalLoss: 0.004342 | Perceptual: 0.000000 | Recon: 0.004327 | KL: 0.000001
# Epoch [135/250] | Time: 92.18s | TotalLoss: 0.004344 | Perceptual: 0.000000 | Recon: 0.004325 | KL: 0.000002
# Epoch [136/250] | Time: 92.72s | TotalLoss: 0.004344 | Perceptual: 0.000000 | Recon: 0.004327 | KL: 0.000002
# Epoch [137/250] | Time: 92.04s | TotalLoss: 0.004342 | Perceptual: 0.000000 | Recon: 0.004325 | KL: 0.000002
# Epoch [138/250] | Time: 92.21s | TotalLoss: 0.004343 | Perceptual: 0.000000 | Recon: 0.004325 | KL: 0.000002
# Epoch [139/250] | Time: 92.13s | TotalLoss: 0.004338 | Perceptual: 0.000000 | Recon: 0.004323 | KL: 0.000002
# Epoch [140/250] | Time: 92.16s | TotalLoss: 0.004338 | Perceptual: 0.000000 | Recon: 0.004323 | KL: 0.000001
# Epoch [141/250] | Time: 92.08s | TotalLoss: 0.004328 | Perceptual: 0.000000 | Recon: 0.004322 | KL: 0.000001
# Epoch [142/250] | Time: 92.08s | TotalLoss: 0.004331 | Perceptual: 0.000000 | Recon: 0.004320 | KL: 0.000001
# Epoch [143/250] | Time: 92.64s | TotalLoss: 0.004334 | Perceptual: 0.000000 | Recon: 0.004320 | KL: 0.000001
# Epoch [144/250] | Time: 92.29s | TotalLoss: 0.004334 | Perceptual: 0.000000 | Recon: 0.004320 | KL: 0.000001
# Epoch [145/250] | Time: 91.90s | TotalLoss: 0.004335 | Perceptual: 0.000000 | Recon: 0.004319 | KL: 0.000002
# Epoch [146/250] | Time: 91.84s | TotalLoss: 0.004329 | Perceptual: 0.000000 | Recon: 0.004319 | KL: 0.000001
# Epoch [147/250] | Time: 92.23s | TotalLoss: 0.004333 | Perceptual: 0.000000 | Recon: 0.004319 | KL: 0.000001
# Epoch [148/250] | Time: 88.83s | TotalLoss: 0.004329 | Perceptual: 0.000000 | Recon: 0.004318 | KL: 0.000001
# Epoch [149/250] | Time: 92.95s | TotalLoss: 0.004334 | Perceptual: 0.000000 | Recon: 0.004318 | KL: 0.000002
# Epoch [150/250] | Time: 92.24s | TotalLoss: 0.004327 | Perceptual: 0.000000 | Recon: 0.004317 | KL: 0.000001
# Validation | TotalLoss: 0.004365 | Perceptual: 0.000000 | Recon: 0.004356 | KL: 0.000001
# Epoch [151/250] | Time: 91.95s | TotalLoss: 0.004321 | Perceptual: 0.000000 | Recon: 0.004316 | KL: 0.000000
# Epoch [152/250] | Time: 92.36s | TotalLoss: 0.004322 | Perceptual: 0.000000 | Recon: 0.004316 | KL: 0.000001
# Epoch [153/250] | Time: 92.35s | TotalLoss: 0.004330 | Perceptual: 0.000000 | Recon: 0.004317 | KL: 0.000001
# Epoch [154/250] | Time: 92.38s | TotalLoss: 0.004324 | Perceptual: 0.000000 | Recon: 0.004314 | KL: 0.000001
# Epoch [155/250] | Time: 92.23s | TotalLoss: 0.004326 | Perceptual: 0.000000 | Recon: 0.004314 | KL: 0.000001
# Epoch [156/250] | Time: 92.77s | TotalLoss: 0.004327 | Perceptual: 0.000000 | Recon: 0.004316 | KL: 0.000001
# Epoch [157/250] | Time: 92.30s | TotalLoss: 0.004322 | Perceptual: 0.000000 | Recon: 0.004313 | KL: 0.000001
# Epoch [158/250] | Time: 92.04s | TotalLoss: 0.004324 | Perceptual: 0.000000 | Recon: 0.004314 | KL: 0.000001
# Epoch [159/250] | Time: 92.38s | TotalLoss: 0.004324 | Perceptual: 0.000000 | Recon: 0.004313 | KL: 0.000001
# Epoch [160/250] | Time: 92.09s | TotalLoss: 0.004322 | Perceptual: 0.000000 | Recon: 0.004312 | KL: 0.000001
# Epoch [161/250] | Time: 92.36s | TotalLoss: 0.004315 | Perceptual: 0.000000 | Recon: 0.004312 | KL: 0.000000
# Epoch [162/250] | Time: 92.58s | TotalLoss: 0.004318 | Perceptual: 0.000000 | Recon: 0.004311 | KL: 0.000001
# Epoch [163/250] | Time: 92.16s | TotalLoss: 0.004320 | Perceptual: 0.000000 | Recon: 0.004313 | KL: 0.000001
# Epoch [164/250] | Time: 92.17s | TotalLoss: 0.004320 | Perceptual: 0.000000 | Recon: 0.004311 | KL: 0.000001
# Epoch [165/250] | Time: 92.16s | TotalLoss: 0.004319 | Perceptual: 0.000000 | Recon: 0.004309 | KL: 0.000001
# Epoch [166/250] | Time: 91.94s | TotalLoss: 0.004319 | Perceptual: 0.000000 | Recon: 0.004310 | KL: 0.000001
# Epoch [167/250] | Time: 92.19s | TotalLoss: 0.004317 | Perceptual: 0.000000 | Recon: 0.004309 | KL: 0.000001
# Epoch [168/250] | Time: 92.14s | TotalLoss: 0.004317 | Perceptual: 0.000000 | Recon: 0.004310 | KL: 0.000001
# Epoch [169/250] | Time: 92.91s | TotalLoss: 0.004317 | Perceptual: 0.000000 | Recon: 0.004310 | KL: 0.000001
# Epoch [170/250] | Time: 92.37s | TotalLoss: 0.004319 | Perceptual: 0.000000 | Recon: 0.004311 | KL: 0.000001
# Epoch [171/250] | Time: 92.44s | TotalLoss: 0.004311 | Perceptual: 0.000000 | Recon: 0.004307 | KL: 0.000000
# Epoch [172/250] | Time: 92.55s | TotalLoss: 0.004312 | Perceptual: 0.000000 | Recon: 0.004307 | KL: 0.000000
# Epoch [173/250] | Time: 89.03s | TotalLoss: 0.004312 | Perceptual: 0.000000 | Recon: 0.004306 | KL: 0.000001
# Epoch [174/250] | Time: 92.66s | TotalLoss: 0.004315 | Perceptual: 0.000000 | Recon: 0.004307 | KL: 0.000001
# Epoch [175/250] | Time: 92.93s | TotalLoss: 0.004312 | Perceptual: 0.000000 | Recon: 0.004307 | KL: 0.000001
# Validation | TotalLoss: 0.004355 | Perceptual: 0.000000 | Recon: 0.004346 | KL: 0.000001
# Epoch [176/250] | Time: 92.63s | TotalLoss: 0.004316 | Perceptual: 0.000000 | Recon: 0.004307 | KL: 0.000001
# Epoch [177/250] | Time: 92.31s | TotalLoss: 0.004312 | Perceptual: 0.000000 | Recon: 0.004306 | KL: 0.000001
# Epoch [178/250] | Time: 92.21s | TotalLoss: 0.004312 | Perceptual: 0.000000 | Recon: 0.004307 | KL: 0.000001
# Epoch [179/250] | Time: 92.66s | TotalLoss: 0.004315 | Perceptual: 0.000000 | Recon: 0.004306 | KL: 0.000001
# Epoch [180/250] | Time: 92.45s | TotalLoss: 0.004313 | Perceptual: 0.000000 | Recon: 0.004307 | KL: 0.000001
# Epoch [181/250] | Time: 92.84s | TotalLoss: 0.004307 | Perceptual: 0.000000 | Recon: 0.004305 | KL: 0.000000
# Epoch [182/250] | Time: 92.26s | TotalLoss: 0.004309 | Perceptual: 0.000000 | Recon: 0.004305 | KL: 0.000000
# Epoch [183/250] | Time: 92.11s | TotalLoss: 0.004310 | Perceptual: 0.000000 | Recon: 0.004304 | KL: 0.000001
# Epoch [184/250] | Time: 92.37s | TotalLoss: 0.004308 | Perceptual: 0.000000 | Recon: 0.004303 | KL: 0.000000
# Epoch [185/250] | Time: 92.47s | TotalLoss: 0.004308 | Perceptual: 0.000000 | Recon: 0.004303 | KL: 0.000000
# Epoch [186/250] | Time: 92.55s | TotalLoss: 0.004309 | Perceptual: 0.000000 | Recon: 0.004304 | KL: 0.000001
# Epoch [187/250] | Time: 92.50s | TotalLoss: 0.004309 | Perceptual: 0.000000 | Recon: 0.004303 | KL: 0.000001
# Epoch [188/250] | Time: 92.98s | TotalLoss: 0.004309 | Perceptual: 0.000000 | Recon: 0.004304 | KL: 0.000000
# Epoch [189/250] | Time: 92.85s | TotalLoss: 0.004306 | Perceptual: 0.000000 | Recon: 0.004301 | KL: 0.000001
# Epoch [190/250] | Time: 92.90s | TotalLoss: 0.004305 | Perceptual: 0.000000 | Recon: 0.004301 | KL: 0.000000
# Epoch [191/250] | Time: 92.46s | TotalLoss: 0.004304 | Perceptual: 0.000000 | Recon: 0.004302 | KL: 0.000000
# Epoch [192/250] | Time: 92.76s | TotalLoss: 0.004304 | Perceptual: 0.000000 | Recon: 0.004301 | KL: 0.000000
# Epoch [193/250] | Time: 92.63s | TotalLoss: 0.004306 | Perceptual: 0.000000 | Recon: 0.004301 | KL: 0.000000
# Epoch [194/250] | Time: 93.10s | TotalLoss: 0.004304 | Perceptual: 0.000000 | Recon: 0.004300 | KL: 0.000000
# Epoch [195/250] | Time: 92.63s | TotalLoss: 0.004305 | Perceptual: 0.000000 | Recon: 0.004301 | KL: 0.000000
# Epoch [196/250] | Time: 92.37s | TotalLoss: 0.004302 | Perceptual: 0.000000 | Recon: 0.004299 | KL: 0.000000
# Epoch [197/250] | Time: 92.77s | TotalLoss: 0.004303 | Perceptual: 0.000000 | Recon: 0.004299 | KL: 0.000000
# Epoch [198/250] | Time: 89.05s | TotalLoss: 0.004304 | Perceptual: 0.000000 | Recon: 0.004300 | KL: 0.000000
# Epoch [199/250] | Time: 92.13s | TotalLoss: 0.004304 | Perceptual: 0.000000 | Recon: 0.004299 | KL: 0.000000
# Epoch [200/250] | Time: 92.82s | TotalLoss: 0.004302 | Perceptual: 0.000000 | Recon: 0.004299 | KL: 0.000000
# Validation | TotalLoss: 0.004343 | Perceptual: 0.000000 | Recon: 0.004339 | KL: 0.000000
# Epoch [201/250] | Time: 93.68s | TotalLoss: 0.004301 | Perceptual: 0.000000 | Recon: 0.004299 | KL: 0.000000
# Epoch [202/250] | Time: 92.42s | TotalLoss: 0.004299 | Perceptual: 0.000000 | Recon: 0.004296 | KL: 0.000000
# Epoch [203/250] | Time: 92.13s | TotalLoss: 0.004303 | Perceptual: 0.000000 | Recon: 0.004299 | KL: 0.000000
# Epoch [204/250] | Time: 92.56s | TotalLoss: 0.004301 | Perceptual: 0.000000 | Recon: 0.004298 | KL: 0.000000
# Epoch [205/250] | Time: 92.29s | TotalLoss: 0.004302 | Perceptual: 0.000000 | Recon: 0.004298 | KL: 0.000000
# Epoch [206/250] | Time: 92.32s | TotalLoss: 0.004301 | Perceptual: 0.000000 | Recon: 0.004298 | KL: 0.000000
# Epoch [207/250] | Time: 92.98s | TotalLoss: 0.004301 | Perceptual: 0.000000 | Recon: 0.004298 | KL: 0.000000
# Epoch [208/250] | Time: 92.34s | TotalLoss: 0.004302 | Perceptual: 0.000000 | Recon: 0.004298 | KL: 0.000000
# Epoch [209/250] | Time: 92.44s | TotalLoss: 0.004301 | Perceptual: 0.000000 | Recon: 0.004297 | KL: 0.000000
# Epoch [210/250] | Time: 92.28s | TotalLoss: 0.004301 | Perceptual: 0.000000 | Recon: 0.004298 | KL: 0.000000
# Epoch [211/250] | Time: 92.57s | TotalLoss: 0.004299 | Perceptual: 0.000000 | Recon: 0.004297 | KL: 0.000000
# Epoch [212/250] | Time: 92.70s | TotalLoss: 0.004299 | Perceptual: 0.000000 | Recon: 0.004297 | KL: 0.000000
# Epoch [213/250] | Time: 93.05s | TotalLoss: 0.004298 | Perceptual: 0.000000 | Recon: 0.004295 | KL: 0.000000
# Epoch [214/250] | Time: 92.45s | TotalLoss: 0.004298 | Perceptual: 0.000000 | Recon: 0.004295 | KL: 0.000000
# Epoch [215/250] | Time: 92.60s | TotalLoss: 0.004297 | Perceptual: 0.000000 | Recon: 0.004295 | KL: 0.000000
# Epoch [216/250] | Time: 92.71s | TotalLoss: 0.004299 | Perceptual: 0.000000 | Recon: 0.004295 | KL: 0.000000
# Epoch [217/250] | Time: 92.24s | TotalLoss: 0.004297 | Perceptual: 0.000000 | Recon: 0.004294 | KL: 0.000000
# Epoch [218/250] | Time: 92.56s | TotalLoss: 0.004298 | Perceptual: 0.000000 | Recon: 0.004295 | KL: 0.000000
# Epoch [219/250] | Time: 92.33s | TotalLoss: 0.004298 | Perceptual: 0.000000 | Recon: 0.004295 | KL: 0.000000
# Epoch [220/250] | Time: 93.00s | TotalLoss: 0.004297 | Perceptual: 0.000000 | Recon: 0.004294 | KL: 0.000000
# Epoch [221/250] | Time: 92.35s | TotalLoss: 0.004295 | Perceptual: 0.000000 | Recon: 0.004294 | KL: 0.000000
# Epoch [222/250] | Time: 92.42s | TotalLoss: 0.004296 | Perceptual: 0.000000 | Recon: 0.004294 | KL: 0.000000
# Epoch [223/250] | Time: 92.53s | TotalLoss: 0.004295 | Perceptual: 0.000000 | Recon: 0.004293 | KL: 0.000000
# Epoch [224/250] | Time: 89.17s | TotalLoss: 0.004296 | Perceptual: 0.000000 | Recon: 0.004294 | KL: 0.000000
# Epoch [225/250] | Time: 92.16s | TotalLoss: 0.004294 | Perceptual: 0.000000 | Recon: 0.004292 | KL: 0.000000
# Validation | TotalLoss: 0.004337 | Perceptual: 0.000000 | Recon: 0.004336 | KL: 0.000000
# Epoch [226/250] | Time: 96.14s | TotalLoss: 0.004296 | Perceptual: 0.000000 | Recon: 0.004294 | KL: 0.000000
# Epoch [227/250] | Time: 91.96s | TotalLoss: 0.004297 | Perceptual: 0.000000 | Recon: 0.004294 | KL: 0.000000
# Epoch [228/250] | Time: 92.48s | TotalLoss: 0.004296 | Perceptual: 0.000000 | Recon: 0.004295 | KL: 0.000000
# Epoch [229/250] | Time: 92.60s | TotalLoss: 0.004294 | Perceptual: 0.000000 | Recon: 0.004292 | KL: 0.000000
# Epoch [230/250] | Time: 92.48s | TotalLoss: 0.004296 | Perceptual: 0.000000 | Recon: 0.004293 | KL: 0.000000
# Epoch [231/250] | Time: 92.41s | TotalLoss: 0.004294 | Perceptual: 0.000000 | Recon: 0.004293 | KL: 0.000000
# Epoch [232/250] | Time: 92.78s | TotalLoss: 0.004295 | Perceptual: 0.000000 | Recon: 0.004293 | KL: 0.000000
# Epoch [233/250] | Time: 92.97s | TotalLoss: 0.004294 | Perceptual: 0.000000 | Recon: 0.004293 | KL: 0.000000
# Epoch [234/250] | Time: 92.24s | TotalLoss: 0.004294 | Perceptual: 0.000000 | Recon: 0.004292 | KL: 0.000000
# Epoch [235/250] | Time: 92.25s | TotalLoss: 0.004293 | Perceptual: 0.000000 | Recon: 0.004291 | KL: 0.000000
# Epoch [236/250] | Time: 92.29s | TotalLoss: 0.004294 | Perceptual: 0.000000 | Recon: 0.004292 | KL: 0.000000
# Epoch [237/250] | Time: 92.41s | TotalLoss: 0.004290 | Perceptual: 0.000000 | Recon: 0.004289 | KL: 0.000000
# Epoch [238/250] | Time: 92.24s | TotalLoss: 0.004294 | Perceptual: 0.000000 | Recon: 0.004293 | KL: 0.000000
# Epoch [239/250] | Time: 93.41s | TotalLoss: 0.004293 | Perceptual: 0.000000 | Recon: 0.004291 | KL: 0.000000
# Epoch [240/250] | Time: 94.07s | TotalLoss: 0.004292 | Perceptual: 0.000000 | Recon: 0.004290 | KL: 0.000000
# Epoch [241/250] | Time: 92.54s | TotalLoss: 0.004291 | Perceptual: 0.000000 | Recon: 0.004290 | KL: 0.000000
# Epoch [242/250] | Time: 92.69s | TotalLoss: 0.004291 | Perceptual: 0.000000 | Recon: 0.004290 | KL: 0.000000
# Epoch [243/250] | Time: 92.56s | TotalLoss: 0.004293 | Perceptual: 0.000000 | Recon: 0.004292 | KL: 0.000000
# Epoch [244/250] | Time: 98.96s | TotalLoss: 0.004291 | Perceptual: 0.000000 | Recon: 0.004290 | KL: 0.000000
# Epoch [245/250] | Time: 92.33s | TotalLoss: 0.004292 | Perceptual: 0.000000 | Recon: 0.004290 | KL: 0.000000
# Epoch [246/250] | Time: 92.16s | TotalLoss: 0.004292 | Perceptual: 0.000000 | Recon: 0.004291 | KL: 0.000000
# Epoch [247/250] | Time: 92.25s | TotalLoss: 0.004293 | Perceptual: 0.000000 | Recon: 0.004291 | KL: 0.000000
# Epoch [248/250] | Time: 92.53s | TotalLoss: 0.004291 | Perceptual: 0.000000 | Recon: 0.004289 | KL: 0.000000
# Epoch [249/250] | Time: 88.79s | TotalLoss: 0.004291 | Perceptual: 0.000000 | Recon: 0.004290 | KL: 0.000000
# Epoch [250/250] | Time: 91.98s | TotalLoss: 0.004292 | Perceptual: 0.000000 | Recon: 0.004290 | KL: 0.000000
# Validation | TotalLoss: 0.004334 | Perceptual: 0.000000 | Recon: 0.004333 | KL: 0.000000
# Checkpoint saved: ./checkpoints/vdvae2_epoch_250.pth
# Total Training Time: 22390.80s

# %%
# Plot loss history
plt.figure(figsize=(10, 5))
plt.plot(loss_history["total_loss"], label="Total Loss")
# plt.plot(loss_history["recon_loss"], label="Reconstruction Loss")
# plt.plot(loss_history["kl_loss"], label="KL Divergence")
# plt.plot(loss_history["perceptual_loss"], label="Perceptual Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Losses")
plt.legend()
plt.show()

# %%
# Plot validation loss history
plt.figure(figsize=(10, 5))
plt.plot(val_loss_history["total_loss"], label="Total Loss")
# plt.plot(val_loss_history["recon_loss"], label="Reconstruction Loss")
# plt.plot(val_loss_history["kl_loss"], label="KL Divergence")
# plt.plot(val_loss_history["perceptual_loss"], label="Perceptual Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Validation Losses")
plt.legend()
plt.show()

# %%
# Generate and Visualize Random Samples
def visualize_samples(model, num_samples=5):
    model.eval()
    with torch.no_grad():
        fig, axs = plt.subplots(num_samples, 3, figsize=(6, num_samples * 2))  # Reduced figure size

        # Randomly select `num_samples` indices from the validation dataset
        random_indices = random.sample(range(len(val_dataset)), num_samples)

        for i, idx in enumerate(random_indices):
            hr_img, lr_img = val_dataset[idx]  # Get a random sample
            hr_img, lr_img = hr_img.unsqueeze(0), lr_img.unsqueeze(0)

            # Predict 32x32 from 16x16 input
            recon_img = model.sample(lr_img)

            # Convert tensors to numpy for visualization
            lr_img_np = lr_img.cpu().numpy().squeeze()  # (3, 16, 16) for color
            hr_img_np = hr_img.cpu().numpy().squeeze()  # (3, 32, 32)
            recon_img_np = recon_img.cpu().numpy().squeeze()  # (3, 32, 32)

            # Permute dimensions from (C, H, W) → (H, W, C) for Matplotlib
            lr_img_np = np.transpose(lr_img_np, (1, 2, 0))  # Now (16, 16, 3)
            hr_img_np = np.transpose(hr_img_np, (1, 2, 0))  # Now (32, 32, 3)
            recon_img_np = np.transpose(recon_img_np, (1, 2, 0))  # Now (32, 32, 3)

            # Plot images with smaller size
            axs[i, 0].imshow(lr_img_np)
            axs[i, 0].set_title("16x16 Input", fontsize=8)
            axs[i, 0].axis("off")

            axs[i, 1].imshow(recon_img_np)
            axs[i, 1].set_title("32x32 Prediction", fontsize=8)
            axs[i, 1].axis("off")

            axs[i, 2].imshow(hr_img_np)
            axs[i, 2].set_title("32x32 Ground Truth", fontsize=8)
            axs[i, 2].axis("off")

        # Adjust layout for smaller images
        plt.subplots_adjust(wspace=0.1, hspace=0.3)  # Reduce space between images
        plt.show()

# Run visualization
visualize_samples(model, num_samples=5)

# %%
from util import save_model

save_model(model, "cifar_vdvae22.pth")

# %%
from util import load_model

model = HierarchicalVDVAE(in_channels=num_channels, latent_dims=latent_dims).to(DEVICE)
model = load_model(model, "cifar_vdvae22.pth")

# %%
x, x_inp = val_dataset.get_samples(64)
x = x.to(DEVICE)
x_inp = x_inp.to(DEVICE)
x_hat = model.sample(x_inp)

# %%
import torch.nn.functional as F
from piq import psnr, ssim, brisque, LPIPS

def validation_scores(model, HR, LR):
    SR = model.sample(LR)

    psnr_val = psnr(HR, SR, data_range=1.0)

    ssim_val = ssim(HR, SR, data_range=1.0, reduction='none')

    lpips = LPIPS()
    lpips_val = lpips(HR, SR)

    brisque_val = brisque(SR)

    HR_downsampled = F.interpolate(HR, size=(LR.size(2), LR.size(3)), mode='bicubic', align_corners=False)
    HR_downsampled = (HR_downsampled - HR_downsampled.min()) / (HR_downsampled.max() - HR_downsampled.min())

    psnr_consistency_val = psnr(LR, HR_downsampled, data_range=1.0)

    mse_diversity_val = 0
    lpips_diversity_val = 0
    n_samples = 16
    for i in range(n_samples):
        LR_input = LR[i].unsqueeze(0)
        LR_input = LR_input.repeat(32, 1, 1, 1)
        HR_reference = HR[i].unsqueeze(0)
        HR_reference = HR_reference.repeat(32, 1, 1, 1)
        SR = model.sample(LR_input)
        mse_diversity_val += F.mse_loss(HR_reference, SR, reduction='mean')
        lpips_diversity_val += lpips(HR_reference, SR)
    mse_diversity_val /= n_samples
    lpips_diversity_val /= n_samples

    return psnr_val, ssim_val, lpips_val, brisque_val, psnr_consistency_val, mse_diversity_val, lpips_diversity_val

# %%
psnr_val, ssim_val, lpips_val, brisque_val, psnr_consistency_val, mse_diversity_val, lpips_diversity_val = validation_scores(model, x, x_inp)
print("PSNR:", psnr_val)
print("SSIM:", ssim_val.mean())
print("LPIPS:", lpips_val)
print("BRISQUE:", brisque_val)
print("PSNR Consistency:", psnr_consistency_val)
print("MSE Diversity:", mse_diversity_val)
print("LPIPS Diversity:", lpips_diversity_val)
# Out:
# PSNR: tensor(5.8304, device='cuda:0', grad_fn=<MeanBackward1>)
# SSIM: tensor(0.0134, device='cuda:0', grad_fn=<MeanBackward0>)
# LPIPS: tensor(0.7922, device='cuda:0', grad_fn=<MeanBackward1>)
# BRISQUE: tensor(145.3841, device='cuda:0', grad_fn=<MeanBackward1>)
# PSNR Consistency: tensor(28.5774, device='cuda:0')
# MSE Diversity: tensor(0.2895, device='cuda:0', grad_fn=<DivBackward0>)
# LPIPS Diversity: tensor(0.7851, device='cuda:0', grad_fn=<DivBackward0>)

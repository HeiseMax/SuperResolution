# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including PyTorch, PyTorch Lightning, and torchvision.

# %%
# Import PyTorch and PyTorch Lightning
import torch
import torch.nn as nn
import torch.nn.functional as nnf
import torch.optim as optim
from torch.utils.data import Dataset
import pytorch_lightning as pl

# Import torchvision for the MNIST dataset and transformations
from torchvision import datasets, transforms

# Import other necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Define the VAE Model
# Define the convolutional VAE model architecture, including the encoder and decoder networks.

# %%
class Encoder(nn.Module):
    def __init__(self, input_channels, latent_dim, hidden_dims=None):
        super(Encoder, self).__init__()
        self.latent_dim = latent_dim
        self.input_channels = input_channels

        if hidden_dims is None:
            hidden_dims = [32, 128]#, 256, 512]

        # Encoder
        modules = []
        in_channels = input_channels
        for h_dim in hidden_dims:
            modules.append(
                nn.Sequential(
                    nn.Conv2d(in_channels, out_channels=h_dim, kernel_size=3, stride=2, padding=1),
                    nn.BatchNorm2d(h_dim),
                    nn.LeakyReLU()
                )
            )
            in_channels = h_dim

        self.encoder = nn.Sequential(*modules)
        self.fc_mu = nn.Linear(hidden_dims[-1]*16, latent_dim)
        self.fc_var = nn.Linear(hidden_dims[-1]*16, latent_dim)
    
    def forward(self, LR):
        z = self.encoder(LR)
        z = torch.flatten(z, start_dim=1)
        mean = self.fc_mu(z)
        log_var = self.fc_var(z)
        return [mean, log_var]

# %%
class Decoder(nn.Module):
    def __init__(self, input_channels, latent_dim, hidden_dims=None):
        super(Decoder, self).__init__()
        self.latent_dim = latent_dim
        self.input_channels = input_channels

        if hidden_dims is None:
            hidden_dims = [32, 64, 128]
        hidden_dims.reverse()

        modules = []
        self.decoder_input = nn.Linear(latent_dim, hidden_dims[0] * 16)

        for i in range(len(hidden_dims) - 1):
            modules.append(
                nn.Sequential(
                    nn.ConvTranspose2d(hidden_dims[i],
                                        hidden_dims[i + 1],
                                        kernel_size=3,
                                        stride=2,
                                        padding=1,
                                        output_padding=1),
                    nn.BatchNorm2d(hidden_dims[i + 1]),
                    nn.LeakyReLU()
                )
            )

        self.decoder = nn.Sequential(*modules)

        self.final_layer = nn.Sequential(
            nn.ConvTranspose2d(hidden_dims[-1],
                                hidden_dims[-1],
                                kernel_size=3,
                                stride=2,
                                padding=1,
                                output_padding=1),
            nn.BatchNorm2d(hidden_dims[-1]),
            nn.LeakyReLU(),
            nn.Conv2d(hidden_dims[-1], out_channels=input_channels,
                        kernel_size=3, padding=1),
            nn.Sigmoid()
        )
        
    def forward(self, z):
        SR = self.decoder_input(z)
        SR = SR.view(-1, 128, 4, 4)
        SR = self.decoder(SR)
        SR = self.final_layer(SR)
        return SR

# %%
from piq import psnr, ssim, brisque, LPIPS

def validation_scores(model, HR, LR):
    SR, _, _ = model(LR)

    psnr_val = psnr(HR, SR, data_range=1.0)

    ssim_val = ssim(HR, SR, data_range=1.0, reduction='none')

    lpips = LPIPS()
    lpips_val = lpips(HR, SR)

    brisque_val = brisque(SR)

    HR_downsampled = nnf.interpolate(HR, size=(LR.size(2), LR.size(3)), mode='bicubic', align_corners=False)
    HR_downsampled = (HR_downsampled - HR_downsampled.min()) / (HR_downsampled.max() - HR_downsampled.min())

    psnr_consistency_val = psnr(LR, HR_downsampled, data_range=1.0)

    mse_diversity_val = 0
    lpips_diversity_val = 0
    n_samples = 16
    for i in range(n_samples):
        LR_input = LR[i].unsqueeze(0)
        LR_input = LR_input.repeat(32, 1, 1, 1)
        HR_reference = HR[i].unsqueeze(0)
        HR_reference = HR_reference.repeat(32, 1, 1, 1)
        SR, _, _ = model(LR_input)
        mse_diversity_val += nn.functional.mse_loss(HR_reference, SR, reduction='mean')
        lpips_diversity_val += lpips(HR_reference, SR)
    mse_diversity_val /= n_samples
    lpips_diversity_val /= n_samples

    return psnr_val, ssim_val, lpips_val, brisque_val, psnr_consistency_val, mse_diversity_val, lpips_diversity_val

# %%
class VAE(pl.LightningModule):
    def __init__(self, encoder, decoder):
        super(VAE, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def reparameterize(self, mean, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return eps * std + mean

    def forward(self, LR):
        mean, log_var = self.encoder(LR)
        z = self.reparameterize(mean, log_var)
        SR = self.decoder(z)
        return SR, mean, log_var

    def loss_function(self, SR, HR, mean, log_var):
        recons_loss = nn.functional.binary_cross_entropy(HR, SR, reduction='sum')
        kld_loss = -0.5 * torch.sum(1+ log_var - mean.pow(2) - log_var.exp())
        # recons_loss = nn.functional.mse_loss(SR, HR)
        # kld_loss = torch.mean(-0.5 * torch.sum(1 + log_var - mean ** 2 - log_var.exp(), dim=1), dim=0)
        return (recons_loss + kld_loss) / HR.size(0)

    def training_step(self, batch, batch_idx):
        HR, LR = batch
        SR, mean, log_var = self(LR)
        loss = self.loss_function(SR, HR, mean, log_var)
        self.log('train_loss', loss)
        return loss

    def configure_optimizers(self):
        return optim.Adam(self.parameters(), lr=1e-4)
    
    def validation_step(self, batch, batch_idx):
        HR, LR = batch
        SR, mean, log_var = self(LR)
        loss = self.loss_function(SR, HR, mean, log_var)
        self.log('val_loss', loss)

        if self.current_epoch % 10 == 9 and batch_idx == 0:
            psnr_val, ssim_val, lpips_val, brisque_val, psnr_consistency_val, mse_diversity_val, lpips_diversity_val = validation_scores(self, HR, LR)
            self.log('psnr_val', psnr_val)
            self.log('ssim_val', ssim_val.mean())
            self.log('lpips_val', lpips_val)
            self.log('brisque_val', brisque_val)
            self.log('psnr_consistency_val', psnr_consistency_val)
            self.log('mse_diversity_val', mse_diversity_val)
            self.log('lpips_diversity_val', lpips_diversity_val)
            self.logger.experiment.add_figure("Test Data Reconstructions", self.sample_images(LR[:32], HR[:32]), global_step=self.trainer.global_step)
        return loss

    def sample_images(self, LR, HR):
        recon = self(LR)[0].detach().cpu().permute(0, 2, 3, 1)
        gt = HR.detach().cpu().permute(0, 2, 3, 1)
        fig, axes = plt.subplots(8, 8, figsize=(8, 8))
        for i in range(4):
            for j in range(8):
                ax = axes[2*i, j]
                ax.imshow(gt[i*8+j].squeeze(), cmap='gray')
                ax.axis('off')
                ax.set_title('Original')
                
                ax = axes[2*i+1, j]
                ax.imshow(recon[i*8+j].squeeze(), cmap='gray')
                ax.axis('off')
                ax.set_title('Reconstruction')
        return fig

# %% [markdown]
# # Prepare the CIFAR10 Dataset
# Load and preprocess the CIFAR10 dataset using torchvision datasets and transforms.

# %%
class CIFAR_SR(Dataset):    
    def __init__(self, scale_factor=0.5, split="train", download=True):
        self.scale_factor = scale_factor

        match split:
            case "train":
                train = True
            case "test":
                train = False
            case other:
                raise NotImplementedError(f"Unrecognized split: '{other}'")
        
        transform = transforms.Compose([
            # transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
            transforms.ToTensor(),
        ])
        self.dataset = datasets.CIFAR10(root="./data", train=train, transform=transform, download=download)

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, index):
        HR, _ = self.dataset[index]
        LR = nnf.interpolate(HR.unsqueeze(0), scale_factor=self.scale_factor, mode='bicubic', align_corners=False)[0]
        LR = (LR - LR.min()) / (LR.max() - LR.min())
        return HR, LR
    
    def get_samples(self, n_samples):
        HR_samples = []
        LR_samples = []
        for i in range(n_samples):
            ind = np.random.randint(len(self))
            HR, LR = self[ind]
            HR_samples.append(HR)
            LR_samples.append(LR)
        return torch.stack(HR_samples, dim=0), torch.stack(LR_samples, dim=0)

# %%
# Load the CIFAR dataset
train_dataset = CIFAR_SR(split="train")
val_dataset = CIFAR_SR(split="test")

# Create data loaders for training and validation
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=1024, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=512, shuffle=False)

# %% [markdown]
# # Train the Model
# Set up the PyTorch Lightning Trainer and train the VAE model on the MNIST dataset.

# %%
# Initialize the VAE model
encoder = Encoder(input_channels=3, latent_dim=50)
decoder = Decoder(input_channels=3, latent_dim=50)
vae_model = VAE(encoder, decoder)
# vae_model = VAE()

# Initialize the PyTorch Lightning Trainer
trainer = pl.Trainer(max_epochs=250, accelerator="gpu", check_val_every_n_epoch=5)

# Train the model
trainer.fit(vae_model, train_loader, val_loader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params | Mode
# --------------------------------------------
# 0 | encoder | Encoder | 243 K  | train
# 1 | decoder | Decoder | 207 K  | train
# --------------------------------------------
# 450 K     Trainable params
# 0         Non-trainable params
# 450 K     Total params
# 1.801     Total estimated model params size (MB)
# 29        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:425: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\loops\fit_loop.py:310: The number of training batches (49) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 0:   4%|▍         | 2/49 [00:00<00:20,  2.24it/s, v_num=3]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\trainer\call.py:47, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      46         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 47     return trainer_fn(*args, **kwargs)
#      49 except _TunerExitException:
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\trainer\trainer.py:575, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     569 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     570     self.state.fn,
#     571     ckpt_path,
#     572     model_provided=True,
#     573     model_connected=self.lightning_module is not None,
#     574 )
# --> 575 self._run(model, ckpt_path=ckpt_path)
#     577 assert self.state.stopped
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\trainer\trainer.py:982, in Trainer._run(self, model, ckpt_path)
#     979 # ----------------------------
#     980 # RUN THE TRAINER
#     981 # ----------------------------
# --> 982 results = self._run_stage()
#     984 # ----------------------------
#     985 # POST-Training CLEAN UP
#     986 # ----------------------------
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\trainer\trainer.py:1026, in Trainer._run_stage(self)
#    1025 with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1026     self.fit_loop.run()
#    1027 return None
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\loops\fit_loop.py:216, in _FitLoop.run(self)
#     215 self.on_advance_start()
# --> 216 self.advance()
#     217 self.on_advance_end()
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\loops\fit_loop.py:455, in _FitLoop.advance(self)
#     454 assert self._data_fetcher is not None
# --> 455 self.epoch_loop.run(self._data_fetcher)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\loops\training_epoch_loop.py:150, in _TrainingEpochLoop.run(self, data_fetcher)
#     149 try:
# --> 150     self.advance(data_fetcher)
#     151     self.on_advance_end(data_fetcher)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\loops\training_epoch_loop.py:293, in _TrainingEpochLoop.advance(self, data_fetcher)
#     292     batch = trainer.lightning_module._on_before_batch_transfer(batch, dataloader_idx=0)
# --> 293     batch = call._call_strategy_hook(trainer, "batch_to_device", batch, dataloader_idx=0)
#     295 self.batch_progress.increment_ready()
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\trainer\call.py:323, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     322 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 323     output = fn(*args, **kwargs)
#     325 # restore current_fx when nested context
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\strategies\strategy.py:278, in Strategy.batch_to_device(self, batch, device, dataloader_idx)
#     277 if model is not None:
# --> 278     return model._apply_batch_transfer_handler(batch, device=device, dataloader_idx=dataloader_idx)
#     279 return move_data_to_device(batch, device)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\core\module.py:352, in LightningModule._apply_batch_transfer_handler(self, batch, device, dataloader_idx)
#     351 device = device or self.device
# --> 352 batch = self._call_batch_hook("transfer_batch_to_device", batch, device, dataloader_idx)
#     353 batch = self._call_batch_hook("on_after_batch_transfer", batch, dataloader_idx)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\core\module.py:341, in LightningModule._call_batch_hook(self, hook_name, *args)
#     339         trainer_method = call._call_lightning_datamodule_hook
# --> 341     return trainer_method(trainer, hook_name, *args)
#     342 hook = getattr(self, hook_name)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\trainer\call.py:171, in _call_lightning_module_hook(trainer, hook_name, pl_module, *args, **kwargs)
#     170 with trainer.profiler.profile(f"[LightningModule]{pl_module.__class__.__name__}.{hook_name}"):
# --> 171     output = fn(*args, **kwargs)
#     173 # restore current_fx when nested context
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\core\hooks.py:611, in DataHooks.transfer_batch_to_device(self, batch, device, dataloader_idx)
#     565 """Override this hook if your :class:`~torch.utils.data.DataLoader` returns tensors wrapped in a custom data
#     566 structure.
#     567
#    (...)    609
#     610 """
# --> 611 return move_data_to_device(batch, device)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\lightning_fabric\utilities\apply_func.py:110, in move_data_to_device(batch, device)
#     108     return data
# --> 110 return apply_to_collection(batch, dtype=_TransferableDataType, function=batch_to)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\lightning_utilities\core\apply_func.py:67, in apply_to_collection(data, dtype, function, wrong_dtype, include_none, allow_frozen, *args, **kwargs)
#      66 if data.__class__ is list and all(isinstance(x, dtype) for x in data):  # 1d homogeneous list
# ---> 67     return [function(x, *args, **kwargs) for x in data]
#      68 if data.__class__ is tuple and all(isinstance(x, dtype) for x in data):  # 1d homogeneous tuple
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\lightning_fabric\utilities\apply_func.py:104, in move_data_to_device.<locals>.batch_to(data)
#     103     kwargs["non_blocking"] = True
# --> 104 data_output = data.to(device, **kwargs)
#     105 if data_output is not None:
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 11
#       8 trainer = pl.Trainer(max_epochs=250, accelerator="gpu", check_val_every_n_epoch=5)
#      10 # Train the model
# ---> 11 trainer.fit(vae_model, train_loader, val_loader)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\trainer\trainer.py:539, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     537 self.state.status = TrainerStatus.RUNNING
#     538 self.training = True
# --> 539 call._call_and_handle_interrupt(
#     540     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     541 )
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\trainer\call.py:68, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      66 except BaseException as exception:
#      67     _interrupt(trainer, exception)
# ---> 68     trainer._teardown()
#      69     # teardown might access the stage so we reset it after
#      70     trainer.state.stage = None
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\trainer\trainer.py:1005, in Trainer._teardown(self)
#    1002 def _teardown(self) -> None:
#    1003     """This is the Trainer's internal teardown, unrelated to the `teardown` hooks in LightningModule and Callback;
#    1004     those are handled by :meth:`_call_teardown_hook`."""
# -> 1005     self.strategy.teardown()
#    1006     loop = self._active_loop
#    1007     # loop should never be `None` here but it can because we don't know the trainer stage with `ddp_spawn`
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\pytorch_lightning\strategies\strategy.py:532, in Strategy.teardown(self)
#     526 def teardown(self) -> None:
#     527     """This method is called to teardown the training process.
#     528
#     529     It is the right place to release memory and free other resources.
#     530
#     531     """
# --> 532     _optimizers_to_device(self.optimizers, torch.device("cpu"))
#     534     if self.lightning_module is not None:
#     535         log.debug(f"{self.__class__.__name__}: moving model to CPU")
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\lightning_fabric\utilities\optimizer.py:27, in _optimizers_to_device(optimizers, device)
#      25 """Moves optimizer states for a sequence of optimizers to the device."""
#      26 for opt in optimizers:
# ---> 27     _optimizer_to_device(opt, device)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\lightning_fabric\utilities\optimizer.py:41, in _optimizer_to_device(optimizer, device)
#      37 for key, val in v.items():
#      38     # The 'step' parameter needs to remain unmoved (possibly on the CPU) since that is where the optimizer
#      39     # needs it. See https://github.com/pytorch/pytorch/issues/74424
#      40     if key != "step":
# ---> 41         v[key] = move_data_to_device(val, device)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\lightning_fabric\utilities\apply_func.py:110, in move_data_to_device(batch, device)
#     107     # user wrongly implemented the `_TransferableDataType` and forgot to return `self`.
#     108     return data
# --> 110 return apply_to_collection(batch, dtype=_TransferableDataType, function=batch_to)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\lightning_utilities\core\apply_func.py:65, in apply_to_collection(data, dtype, function, wrong_dtype, include_none, allow_frozen, *args, **kwargs)
#      63 # fast path for the most common cases:
#      64 if isinstance(data, dtype):  # single element
# ---> 65     return function(data, *args, **kwargs)
#      66 if data.__class__ is list and all(isinstance(x, dtype) for x in data):  # 1d homogeneous list
#      67     return [function(x, *args, **kwargs) for x in data]
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\lightning_fabric\utilities\apply_func.py:104, in move_data_to_device.<locals>.batch_to(data)
#     102 if isinstance(data, Tensor) and isinstance(device, torch.device) and device.type not in _BLOCKING_DEVICE_TYPES:
#     103     kwargs["non_blocking"] = True
# --> 104 data_output = data.to(device, **kwargs)
#     105 if data_output is not None:
#     106     return data_output
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %% [markdown]
# # Evaluate the Model
# Evaluate the trained VAE model by generating new samples and visualizing the results.

# %%
# Evaluate the Model

# Generate new samples from the trained VAE model
vae_model.eval()
with torch.no_grad():
    input = val_dataset.get_samples(64)[1]
    # Generate new samples
    samples = vae_model(input)[0].cpu()

# Visualize the generated samples
fig, axes = plt.subplots(8, 8, figsize=(8, 8))
for i, ax in enumerate(axes.flatten()):
    ax.imshow(samples[i].permute(1,2,0), cmap='gray')
    ax.axis('off')
plt.show()

# %%
HR, LR = val_dataset.get_samples(64)
psnr_val, ssim_val, lpips_val, brisque_val, psnr_consistency_val, mse_diversity_val, lpips_diversity_val = validation_scores(vae_model, HR, LR)
print(f"PSNR: {psnr_val:.2f} dB")
print(f"SSIM: {ssim_val.mean():.4f}")
print(f"LPIPS: {lpips_val:.4f}")
print(f"BRISQUE: {brisque_val:.4f}")
print(f"PSNR Consistency: {psnr_consistency_val:.2f} dB")
print(f"MSE Diversity: {mse_diversity_val:.4f}")
print(f"LPIPS Diversity: {lpips_diversity_val:.4f}")
# Out:
# PSNR: 13.06 dB
# SSIM: 0.1199
# LPIPS: 0.8262
# BRISQUE: 43.5121
# PSNR Consistency: 26.59 dB
# MSE Diversity: 0.0598
# LPIPS Diversity: 0.8106

# %%
# torch.save(vae_model.state_dict(), "CIFAR_lightning.pth")

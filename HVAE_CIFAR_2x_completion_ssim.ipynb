# %%
import torch
from torchinfo import summary
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from piq import ssim


from utils.metrics import validation_scores
from models.completion.HVAE import ConditionalHierarchicalVAE
from utils.datasets import CIFAR_SR_completion
from utils.utils import gaussian_kl


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
num_epochs = 100
batch_size = 512
scalefactor = 2

path = f"trained_models/HVAE_CIFAR_{scalefactor}x_completion_ssim.pth"

latent_dims = [64, 128, 256]
condition_dims = [32, 64]
channels = [16, 32, 64, 128]
cond_channels = [16, 32]
in_channels = 3
cond_base_width = 32 // scalefactor
model = ConditionalHierarchicalVAE(in_channels=in_channels,
                          #latent_dims=latent_dims,
                          channels=channels,
                          cond_channels=cond_channels,
                          condition_dims=condition_dims,
                          cond_base_width=cond_base_width
                          ).to(device)
print(model.sample(torch.randn(1, in_channels, cond_base_width, cond_base_width).to(device)).shape)
summary(model, input_size=[(1, in_channels, 32, 32), (1, in_channels, cond_base_width, cond_base_width), (1, in_channels, 32, 32)])
# Out:
# torch.Size([1, 3, 32, 32])
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ConditionalHierarchicalVAE                    [1, 3, 32, 32]            21
# ├─ConditionalHierarchicalEncoder: 1-1         [1, 64]                   --
# │    └─Conv2d: 2-1                            [1, 16, 32, 32]           64
# │    └─Conv2d: 2-2                            [1, 32, 16, 16]           8,224
# │    └─Conv2d: 2-3                            [1, 64, 8, 8]             32,832
# │    └─Conv2d: 2-4                            [1, 128, 4, 4]            131,200
# │    └─Linear: 2-5                            [1, 64]                   131,136
# │    └─Linear: 2-6                            [1, 64]                   131,136
# │    └─Linear: 2-7                            [1, 128]                  524,416
# │    └─Linear: 2-8                            [1, 128]                  524,416
# │    └─Linear: 2-9                            [1, 256]                  2,097,408
# │    └─Linear: 2-10                           [1, 256]                  2,097,408
# ├─ConditionalHierarchicalLREncoder: 1-2       [1, 32]                   --
# │    └─Conv2d: 2-11                           [1, 16, 16, 16]           64
# │    └─Conv2d: 2-12                           [1, 32, 8, 8]             8,224
# │    └─Linear: 2-13                           [1, 32]                   65,568
# │    └─Linear: 2-14                           [1, 64]                   262,208
# ├─Linear: 1-3                                 [1, 128]                  8,320
# ├─Linear: 1-4                                 [1, 256]                  33,024
# ├─ConditionalHierarchicalDecoder: 1-5         [1, 3, 32, 32]            --
# │    └─Linear: 2-15                           [1, 2048]                 133,120
# │    └─Linear: 2-16                           [1, 4096]                 528,384
# │    └─Linear: 2-17                           [1, 8192]                 2,105,344
# │    └─Linear: 2-18                           [1, 2048]                 67,584
# │    └─Linear: 2-19                           [1, 4096]                 266,240
# │    └─ConvTranspose2d: 2-20                  [1, 64, 8, 8]             262,208
# │    └─ConvTranspose2d: 2-21                  [1, 32, 16, 16]           65,568
# │    └─ConvTranspose2d: 2-22                  [1, 16, 32, 32]           8,208
# │    └─Conv2d: 2-23                           [1, 3, 32, 32]            51
# ===============================================================================================
# Total params: 9,492,376
# Trainable params: 9,492,376
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 57.91
# ===============================================================================================
# Input size (MB): 0.03
# Forward/backward pass size (MB): 0.72
# Params size (MB): 37.97
# Estimated Total Size (MB): 38.72
# ===============================================================================================

# %%
train_dataset = CIFAR_SR_completion(scale_factor=scalefactor, split='train')
test_dataset = CIFAR_SR_completion(scale_factor=scalefactor, split='test')

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
num_train_data = len(train_dataset)
print(f"Dataset Loaded: {len(train_dataset)} training samples, {len(test_dataset)} validation samples")
# Out:
# Dataset Loaded: 50000 training samples, 10000 validation samples

# %%
# Adam opt
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = lambda x, y: -ssim(x, y, data_range=1.0)  # SSIM loss
# Learning Rate Scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.9)

# %%
loss_list = []
recon_loss_list = []
kl_loss_list = []

# %%
kl_weight = 1000

for epoch in range(num_epochs):
    model.train()
    
    total_loss = 0
    total_recon_loss = 0
    total_kl_loss = 0

    for HR, LR, LR_up in train_loader:
        optimizer.zero_grad()

        recon_imgs, latents = model(HR, LR, LR_up)

        recon_loss = criterion(recon_imgs, HR)
        kl_loss = 0
        for mu, logvar in latents:
            kl_loss += torch.mean(gaussian_kl(mu, logvar, torch.zeros_like(mu), torch.zeros_like(logvar)))
        loss = recon_loss + kl_weight * kl_loss

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        total_recon_loss += recon_loss.item()
        total_kl_loss += kl_loss.item()

    scheduler.step()    

    print(f"Epoch [{epoch+1}/{num_epochs}] | Loss: {total_loss:.6f} | Recon Loss: {total_recon_loss:.6f} | KL Loss: {total_kl_loss:.6f}")
    loss_list.append(total_loss)
    recon_loss_list.append(total_recon_loss)
    kl_loss_list.append(total_kl_loss)
# Out:
# Epoch [1/100] | Loss: 7532.787884 | Recon Loss: -69.974484 | KL Loss: 7.602762
# Epoch [2/100] | Loss: -15.289432 | Recon Loss: -74.483701 | KL Loss: 0.059194
# Epoch [3/100] | Loss: -35.918234 | Recon Loss: -76.156872 | KL Loss: 0.040239
# Epoch [4/100] | Loss: -48.747037 | Recon Loss: -79.625643 | KL Loss: 0.030879
# Epoch [5/100] | Loss: -56.286052 | Recon Loss: -81.364531 | KL Loss: 0.025078
# Epoch [6/100] | Loss: -61.338183 | Recon Loss: -82.279499 | KL Loss: 0.020941
# Epoch [7/100] | Loss: -64.939656 | Recon Loss: -82.854279 | KL Loss: 0.017915
# Epoch [8/100] | Loss: -67.513286 | Recon Loss: -83.220475 | KL Loss: 0.015707
# Epoch [9/100] | Loss: -69.600995 | Recon Loss: -83.464950 | KL Loss: 0.013864
# Epoch [10/100] | Loss: -71.233144 | Recon Loss: -83.703450 | KL Loss: 0.012470
# Epoch [11/100] | Loss: -72.624989 | Recon Loss: -83.864724 | KL Loss: 0.011240
# Epoch [12/100] | Loss: -73.733195 | Recon Loss: -84.006250 | KL Loss: 0.010273
# Epoch [13/100] | Loss: -74.704063 | Recon Loss: -84.152301 | KL Loss: 0.009448
# Epoch [14/100] | Loss: -75.603901 | Recon Loss: -84.275389 | KL Loss: 0.008671
# Epoch [15/100] | Loss: -74.260793 | Recon Loss: -84.377425 | KL Loss: 0.010117
# Epoch [16/100] | Loss: -76.060815 | Recon Loss: -84.489707 | KL Loss: 0.008429
# Epoch [17/100] | Loss: -62.995854 | Recon Loss: -84.553264 | KL Loss: 0.021557
# Epoch [18/100] | Loss: -40.304256 | Recon Loss: -84.595201 | KL Loss: 0.044291
# Epoch [19/100] | Loss: -71.117920 | Recon Loss: -84.684325 | KL Loss: 0.013566
# Epoch [20/100] | Loss: -78.930633 | Recon Loss: -84.735537 | KL Loss: 0.005805
# Epoch [21/100] | Loss: -79.173670 | Recon Loss: -84.768704 | KL Loss: 0.005595
# Epoch [22/100] | Loss: -79.549610 | Recon Loss: -84.822246 | KL Loss: 0.005273
# Epoch [23/100] | Loss: -79.868577 | Recon Loss: -84.849008 | KL Loss: 0.004980
# Epoch [24/100] | Loss: -79.636084 | Recon Loss: -84.873604 | KL Loss: 0.005238
# Epoch [25/100] | Loss: -80.207760 | Recon Loss: -84.910487 | KL Loss: 0.004703
# Epoch [26/100] | Loss: -80.081396 | Recon Loss: -84.933455 | KL Loss: 0.004852
# Epoch [27/100] | Loss: -64.433470 | Recon Loss: -84.950762 | KL Loss: 0.020517
# Epoch [28/100] | Loss: -80.835612 | Recon Loss: -84.983748 | KL Loss: 0.004148
# Epoch [29/100] | Loss: -81.130972 | Recon Loss: -84.997000 | KL Loss: 0.003866
# Epoch [30/100] | Loss: -69.424879 | Recon Loss: -85.019312 | KL Loss: 0.015594
# Epoch [31/100] | Loss: -81.201679 | Recon Loss: -85.038457 | KL Loss: 0.003837
# Epoch [32/100] | Loss: -81.624030 | Recon Loss: -85.049568 | KL Loss: 0.003426
# Epoch [33/100] | Loss: -81.231256 | Recon Loss: -85.058281 | KL Loss: 0.003827
# Epoch [34/100] | Loss: -81.910683 | Recon Loss: -85.075326 | KL Loss: 0.003165
# Epoch [35/100] | Loss: -81.918725 | Recon Loss: -85.091486 | KL Loss: 0.003173
# Epoch [36/100] | Loss: -61.834453 | Recon Loss: -85.101240 | KL Loss: 0.023267
# Epoch [37/100] | Loss: -82.151594 | Recon Loss: -85.115214 | KL Loss: 0.002964
# Epoch [38/100] | Loss: -82.354012 | Recon Loss: -85.125131 | KL Loss: 0.002771
# Epoch [39/100] | Loss: -82.452269 | Recon Loss: -85.135525 | KL Loss: 0.002683
# Epoch [40/100] | Loss: -82.553290 | Recon Loss: -85.148211 | KL Loss: 0.002595
# Epoch [41/100] | Loss: -82.625229 | Recon Loss: -85.161765 | KL Loss: 0.002537
# Epoch [42/100] | Loss: -82.700862 | Recon Loss: -85.165820 | KL Loss: 0.002465
# Epoch [43/100] | Loss: -82.797970 | Recon Loss: -85.182605 | KL Loss: 0.002385
# Epoch [44/100] | Loss: -82.856034 | Recon Loss: -85.190065 | KL Loss: 0.002334
# Epoch [45/100] | Loss: -79.694078 | Recon Loss: -85.195880 | KL Loss: 0.005502
# Epoch [46/100] | Loss: -82.994894 | Recon Loss: -85.205573 | KL Loss: 0.002211
# Epoch [47/100] | Loss: -83.057659 | Recon Loss: -85.209970 | KL Loss: 0.002152
# Epoch [48/100] | Loss: -73.430268 | Recon Loss: -85.218552 | KL Loss: 0.011788
# Epoch [49/100] | Loss: -82.371872 | Recon Loss: -85.229918 | KL Loss: 0.002858
# Epoch [50/100] | Loss: -83.252208 | Recon Loss: -85.233072 | KL Loss: 0.001981
# Epoch [51/100] | Loss: -83.296928 | Recon Loss: -85.238784 | KL Loss: 0.001942
# Epoch [52/100] | Loss: -83.373349 | Recon Loss: -85.248471 | KL Loss: 0.001875
# Epoch [53/100] | Loss: -83.410880 | Recon Loss: -85.251756 | KL Loss: 0.001841
# Epoch [54/100] | Loss: -83.415545 | Recon Loss: -85.257120 | KL Loss: 0.001842
# Epoch [55/100] | Loss: -83.523166 | Recon Loss: -85.264206 | KL Loss: 0.001741
# Epoch [56/100] | Loss: -83.530068 | Recon Loss: -85.269975 | KL Loss: 0.001740
# Epoch [57/100] | Loss: -82.689703 | Recon Loss: -85.276562 | KL Loss: 0.002587
# Epoch [58/100] | Loss: -83.617078 | Recon Loss: -85.281447 | KL Loss: 0.001664
# Epoch [59/100] | Loss: -83.589098 | Recon Loss: -85.286231 | KL Loss: 0.001697
# Epoch [60/100] | Loss: -81.238222 | Recon Loss: -85.289322 | KL Loss: 0.004051
# Epoch [61/100] | Loss: -83.736487 | Recon Loss: -85.296010 | KL Loss: 0.001560
# Epoch [62/100] | Loss: -83.782126 | Recon Loss: -85.300949 | KL Loss: 0.001519
# Epoch [63/100] | Loss: -83.760677 | Recon Loss: -85.303095 | KL Loss: 0.001542
# Epoch [64/100] | Loss: -83.859518 | Recon Loss: -85.309185 | KL Loss: 0.001450
# Epoch [65/100] | Loss: -83.699138 | Recon Loss: -85.311138 | KL Loss: 0.001612
# Epoch [66/100] | Loss: -82.962843 | Recon Loss: -85.313285 | KL Loss: 0.002350
# Epoch [67/100] | Loss: -83.943492 | Recon Loss: -85.319856 | KL Loss: 0.001376
# Epoch [68/100] | Loss: -83.987165 | Recon Loss: -85.321060 | KL Loss: 0.001334
# Epoch [69/100] | Loss: -83.028763 | Recon Loss: -85.324948 | KL Loss: 0.002296
# Epoch [70/100] | Loss: -84.029060 | Recon Loss: -85.329447 | KL Loss: 0.001300
# Epoch [71/100] | Loss: -84.040665 | Recon Loss: -85.331743 | KL Loss: 0.001291
# Epoch [72/100] | Loss: -83.714803 | Recon Loss: -85.335401 | KL Loss: 0.001621
# Epoch [73/100] | Loss: -84.093513 | Recon Loss: -85.340747 | KL Loss: 0.001247
# Epoch [74/100] | Loss: -84.099269 | Recon Loss: -85.343146 | KL Loss: 0.001244
# Epoch [75/100] | Loss: -83.600067 | Recon Loss: -85.344397 | KL Loss: 0.001744
# Epoch [76/100] | Loss: -84.189456 | Recon Loss: -85.346956 | KL Loss: 0.001158
# Epoch [77/100] | Loss: -84.191986 | Recon Loss: -85.349921 | KL Loss: 0.001158
# Epoch [78/100] | Loss: -83.259848 | Recon Loss: -85.353439 | KL Loss: 0.002094
# Epoch [79/100] | Loss: -84.192191 | Recon Loss: -85.355436 | KL Loss: 0.001163
# Epoch [80/100] | Loss: -84.315040 | Recon Loss: -85.358262 | KL Loss: 0.001043
# Epoch [81/100] | Loss: -84.301208 | Recon Loss: -85.361370 | KL Loss: 0.001060
# Epoch [82/100] | Loss: -84.343917 | Recon Loss: -85.362640 | KL Loss: 0.001019
# Epoch [83/100] | Loss: -84.351912 | Recon Loss: -85.364837 | KL Loss: 0.001013
# Epoch [84/100] | Loss: -84.321069 | Recon Loss: -85.366593 | KL Loss: 0.001046
# Epoch [85/100] | Loss: -84.388736 | Recon Loss: -85.371613 | KL Loss: 0.000983
# Epoch [86/100] | Loss: -84.370423 | Recon Loss: -85.370837 | KL Loss: 0.001000
# Epoch [87/100] | Loss: -84.180909 | Recon Loss: -85.373124 | KL Loss: 0.001192
# Epoch [88/100] | Loss: -84.436383 | Recon Loss: -85.373991 | KL Loss: 0.000938
# Epoch [89/100] | Loss: -84.460779 | Recon Loss: -85.378195 | KL Loss: 0.000917
# Epoch [90/100] | Loss: -84.419076 | Recon Loss: -85.379018 | KL Loss: 0.000960
# Epoch [91/100] | Loss: -84.506495 | Recon Loss: -85.382021 | KL Loss: 0.000876
# Epoch [92/100] | Loss: -84.524647 | Recon Loss: -85.383135 | KL Loss: 0.000858
# Epoch [93/100] | Loss: -84.292768 | Recon Loss: -85.382691 | KL Loss: 0.001090
# Epoch [94/100] | Loss: -84.563434 | Recon Loss: -85.385359 | KL Loss: 0.000822
# Epoch [95/100] | Loss: -84.567426 | Recon Loss: -85.388748 | KL Loss: 0.000821
# Epoch [96/100] | Loss: -84.520064 | Recon Loss: -85.388542 | KL Loss: 0.000868
# Epoch [97/100] | Loss: -84.584560 | Recon Loss: -85.391826 | KL Loss: 0.000807
# Epoch [98/100] | Loss: -84.622897 | Recon Loss: -85.392049 | KL Loss: 0.000769
# Epoch [99/100] | Loss: -84.556747 | Recon Loss: -85.393911 | KL Loss: 0.000837
# Epoch [100/100] | Loss: -84.646885 | Recon Loss: -85.394152 | KL Loss: 0.000747

# %%
torch.save(model.state_dict(), path)

# %%
model.load_state_dict(torch.load(path))
# Out:
# <All keys matched successfully>

# %%
plt.plot(loss_list[1:], label='Total Loss')
plt.plot(recon_loss_list[1:], label='Reconstruction Loss')
plt.plot([l * kl_weight for l in kl_loss_list][1:], label='KL Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot()
# Out:
# []

# %%
HR, LR, LR_up = test_dataset.get_samples(1000)
SR = model.sample(LR)

# %%
def show_image(x, low_res, superres, n):

    fig, axs = plt.subplots(3, n, figsize=(20, 6))
    for i in range(n):
        #figure description above every row in the middle
        if i == 0:
            axs[0, i].set_title('Original')
            axs[1, i].set_title('Low Resolution')
            axs[2, i].set_title('Super Resolution')

        axs[0, i].imshow(x[i].permute(1, 2, 0).detach().cpu().numpy(),)
        axs[0, i].axis('off')

        axs[1, i].imshow(low_res[i].permute(1, 2, 0).detach().cpu().numpy())
        axs[1, i].axis('off')

        axs[2, i].imshow(superres[i].permute(1, 2, 0).detach().cpu().numpy())
        axs[2, i].axis('off')

# %%
show_image(HR, LR, SR, 10)

# %%
n_samp = 3

for i in range(n_samp):
    reference = HR[i]
    reference = reference.repeat(batch_size, 1, 1, 1)
    reference_inp = LR[i].unsqueeze(0).repeat(batch_size, 1, 1, 1)
    
    samples = model.sample(reference_inp).detach().cpu()

    show_image(reference, reference_inp, samples, 10)

# %%
mse_val, perceptual_val, psnr_val, ssim_val, lpips_val, brisque_val, psnr_consistency_val, mse_diversity_val, lpips_diversity_val = validation_scores(model, HR, LR)
print("MSE:", mse_val)
print("Perceptual Loss:", perceptual_val)
print("PSNR:", psnr_val)
print("SSIM:", ssim_val)
print("LPIPS:", lpips_val)
print("BRISQUE:", brisque_val)
print("PSNR Consistency:", psnr_consistency_val)
print("MSE Diversity:", mse_diversity_val)
print("LPIPS Diversity:", lpips_diversity_val)
# Out:
# c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# MSE: 0.0034975800663232803
# Perceptual Loss: 2.7498083114624023
# PSNR: 25.26140594482422
# SSIM: 0.8696746230125427
# LPIPS: 0.20267218351364136
# BRISQUE: 57.646156311035156
# PSNR Consistency: 33.04764938354492
# MSE Diversity: 3.271611030797317e-05
# LPIPS Diversity: 0.0019557218857926273

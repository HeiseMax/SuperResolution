# %%
import torch
from torchinfo import summary
import torch.optim as optim
from torch.nn import MSELoss
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import numpy as np



from utils.metrics import validation_scores
from models.prediction.VAE import ConditionalVAE
from utils.datasets import MNIST_SR
from utils.utils import gaussian_kl


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
num_epochs = 100
batch_size = 512
scalefactor = 4

path = f"trained_models/VAE_MNIST_{scalefactor}x_prediction_mse5.pth"

latent_dims = [32]
condition_dims = [32, 32]
channels = [4, 8, 16, 16]
cond_channels = [8, 16]
in_channels = 1
cond_base_width = 32 // scalefactor
model = ConditionalVAE(in_channels=in_channels,
                          latent_dims=latent_dims,
                          channels=channels,
                          cond_channels=cond_channels,
                          condition_dims=condition_dims,
                          cond_base_width=cond_base_width
                          ).to(device)
print(model.sample(torch.randn(1, in_channels, cond_base_width, cond_base_width).to(device)).shape)
summary(model, input_size=[(1, in_channels, 32, 32), (1, in_channels, cond_base_width, cond_base_width)])
# Out:
# torch.Size([1, 1, 32, 32])
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ConditionalVAE                           [1, 1, 32, 32]            --
# ├─ConditionalVAEEncoder: 1-1             [1, 32]                   --
# │    └─Conv2d: 2-1                       [1, 4, 32, 32]            8
# │    └─Conv2d: 2-2                       [1, 8, 16, 16]            520
# │    └─Conv2d: 2-3                       [1, 16, 8, 8]             2,064
# │    └─Conv2d: 2-4                       [1, 16, 4, 4]             4,112
# │    └─Linear: 2-5                       [1, 32]                   8,224
# │    └─Linear: 2-6                       [1, 32]                   8,224
# ├─ConditionalVAELREncoder: 1-2           [1, 32]                   --
# │    └─Conv2d: 2-7                       [1, 8, 8, 8]              16
# │    └─Conv2d: 2-8                       [1, 16, 4, 4]             2,064
# │    └─Linear: 2-9                       [1, 32]                   8,224
# │    └─Linear: 2-10                      [1, 32]                   8,224
# ├─ConditionalVAEDecoder: 1-3             [1, 1, 32, 32]            8,448
# │    └─Linear: 2-11                      [1, 256]                  8,448
# │    └─ConvTranspose2d: 2-12             [1, 16, 8, 8]             4,112
# │    └─ConvTranspose2d: 2-13             [1, 8, 16, 16]            2,056
# │    └─ConvTranspose2d: 2-14             [1, 4, 32, 32]            516
# │    └─Conv2d: 2-15                      [1, 1, 32, 32]            5
# ==========================================================================================
# Total params: 65,265
# Trainable params: 65,265
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 1.74
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.13
# Params size (MB): 0.23
# Estimated Total Size (MB): 0.37
# ==========================================================================================

# %%
train_dataset = MNIST_SR(scale_factor=scalefactor, split='train')
test_dataset = MNIST_SR(scale_factor=scalefactor, split='test')

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
num_train_data = len(train_dataset)
print(f"Dataset Loaded: {len(train_dataset)} training samples, {len(test_dataset)} validation samples")
# Out:
# Dataset Loaded: 60000 training samples, 10000 validation samples

# %%
# Adam opt
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = MSELoss()
# Learning Rate Scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.9)

# %%
def squared_exponential_kernel(x1, x2, h=1):
    return torch.exp(-torch.sum((x1 - x2) ** 2) / (2 * h))
def inverse_multi_quadratic_kernel(x1, x2, h):
    # print((x1 - x2) ** 2)
    return 1 / torch.sqrt(torch.sum((x1 - x2) ** 2) / h + 1)
def mmd2(X_true, X_pred, kernel):
    # print(kernel(X_pred[1], X_pred[2], 1))
    N = X_true.shape[0] // 2
    M = X_pred.shape[0] // 2
    repulsive = 1 / (M + (M-1)) * torch.sum(torch.tensor([kernel(X_pred[i], X_pred[j], 1) for i in range(M) for j in [k
    for k in range(M) if k != i]]))
    attractive = 2 / (M * N) * torch.sum(torch.tensor([kernel(X_pred[i], X_true[j], 1) for i in range(M) for j in range
    (N)]))
    return repulsive - attractive

# %%
loss_list = []
recon_loss_list = []
kl_loss_list = []
val_loss_list = []
val_recon_loss_list = []
val_kl_loss_list = []

# %%
kl_weight = 100
# mmd_weight = 1

for epoch in range(num_epochs):
    model.train()
    
    total_loss = 0
    total_recon_loss = 0
    total_kl_loss = 0
    total_val_loss = 0
    total_val_recon_loss = 0
    total_val_kl_loss = 0

    for HR, LR in train_loader:
        optimizer.zero_grad()

        recon_imgs, latents, condition = model(HR, LR)

        recon_loss = criterion(recon_imgs, HR)
        kl_loss = 0
        for mu, logvar in latents:
            kl_loss += 0.1*torch.mean(gaussian_kl(mu, logvar, torch.zeros_like(mu), torch.zeros_like(logvar)))
            kl_loss += torch.mean(gaussian_kl(condition[0], condition[1], mu, logvar))
        # mmd = mmd2(condition[0], torch.randn_like(condition[0]), inverse_multi_quadratic_kernel)
        # mmd += mmd2(condition[1], torch.randn_like(condition[1]), inverse_multi_quadratic_kernel)
        loss = recon_loss + kl_weight * kl_loss

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        total_recon_loss += recon_loss.item()
        total_kl_loss += kl_loss.item()

    scheduler.step()

    # if (epoch) % 10 == 0 or epoch == num_epochs-1:
    #     model.eval()
    #     with torch.no_grad():
    #         for HR, LR in val_loader:
    #             recon_imgs, latents, condition = model(HR, LR)
    #             recon_loss = criterion(recon_imgs, HR)
    #             kl_loss = 0
    #             for mu, logvar in latents:
    #                 kl_loss += torch.mean(gaussian_kl(mu, logvar, torch.zeros_like(mu), torch.zeros_like(logvar)))
    #             mmd = mmd2(condition[0], torch.randn_like(condition[0]))
    #             mmd += mmd2(condition[1], torch.randn_like(condition[1]))
    #             loss = recon_loss + kl_weight * kl_loss + mmd_weight * mmd

    #             total_val_loss += loss.item()
    #             total_val_recon_loss += recon_loss.item()
    #             total_val_kl_loss += kl_loss.item()

    #     total_val_loss /= len(val_loader)
    #     total_val_recon_loss /= len(val_loader)
    #     total_val_kl_loss /= len(val_loader)
    #     print(f"Validation Epoch [{epoch+1}/{num_epochs}] | Loss: {total_val_loss:.6f} | Recon Loss: {total_val_recon_loss:.6f} | KL Loss: {total_val_kl_loss:.6f}")
    #     val_loss_list.append(total_val_loss)
    #     val_recon_loss_list.append(total_val_recon_loss)
    #     val_kl_loss_list.append(total_val_kl_loss)

    total_loss /= len(train_loader)
    total_recon_loss /= len(train_loader)
    total_kl_loss /= len(train_loader)
    print(f"Epoch [{epoch+1}/{num_epochs}] | Loss: {total_loss:.6f} | Recon Loss: {total_recon_loss:.6f} | KL Loss: {total_kl_loss:.6f}")
    loss_list.append(total_loss)
    recon_loss_list.append(total_recon_loss)
    kl_loss_list.append(total_kl_loss)
# Out:
# Epoch [1/100] | Loss: 0.251769 | Recon Loss: 0.117604 | KL Loss: 0.001342
# Epoch [2/100] | Loss: 0.068369 | Recon Loss: 0.061476 | KL Loss: 0.000069
# Epoch [3/100] | Loss: 0.061220 | Recon Loss: 0.058102 | KL Loss: 0.000031
# Epoch [4/100] | Loss: 0.059468 | Recon Loss: 0.057664 | KL Loss: 0.000018
# Epoch [5/100] | Loss: 0.058645 | Recon Loss: 0.057468 | KL Loss: 0.000012
# Epoch [6/100] | Loss: 0.058093 | Recon Loss: 0.057283 | KL Loss: 0.000008
# Epoch [7/100] | Loss: 0.057655 | Recon Loss: 0.057069 | KL Loss: 0.000006
# Epoch [8/100] | Loss: 0.057425 | Recon Loss: 0.056980 | KL Loss: 0.000004
# Epoch [9/100] | Loss: 0.057255 | Recon Loss: 0.056910 | KL Loss: 0.000003
# Epoch [10/100] | Loss: 0.057125 | Recon Loss: 0.056851 | KL Loss: 0.000003
# Epoch [11/100] | Loss: 0.057033 | Recon Loss: 0.056810 | KL Loss: 0.000002
# Epoch [12/100] | Loss: 0.056945 | Recon Loss: 0.056761 | KL Loss: 0.000002
# Epoch [13/100] | Loss: 0.056907 | Recon Loss: 0.056752 | KL Loss: 0.000002
# Epoch [14/100] | Loss: 0.056851 | Recon Loss: 0.056718 | KL Loss: 0.000001
# Epoch [15/100] | Loss: 0.056828 | Recon Loss: 0.056712 | KL Loss: 0.000001
# Epoch [16/100] | Loss: 0.056780 | Recon Loss: 0.056678 | KL Loss: 0.000001
# Epoch [17/100] | Loss: 0.056777 | Recon Loss: 0.056689 | KL Loss: 0.000001
# Epoch [18/100] | Loss: 0.056735 | Recon Loss: 0.056643 | KL Loss: 0.000001
# Epoch [19/100] | Loss: 0.056730 | Recon Loss: 0.056660 | KL Loss: 0.000001
# Epoch [20/100] | Loss: 0.056717 | Recon Loss: 0.056653 | KL Loss: 0.000001
# Epoch [21/100] | Loss: 0.056722 | Recon Loss: 0.056644 | KL Loss: 0.000001
# Epoch [22/100] | Loss: 0.056669 | Recon Loss: 0.056615 | KL Loss: 0.000001
# Epoch [23/100] | Loss: 0.056663 | Recon Loss: 0.056615 | KL Loss: 0.000000
# Epoch [24/100] | Loss: 0.056643 | Recon Loss: 0.056588 | KL Loss: 0.000001
# Epoch [25/100] | Loss: 0.056636 | Recon Loss: 0.056596 | KL Loss: 0.000000
# Epoch [26/100] | Loss: 0.056631 | Recon Loss: 0.056593 | KL Loss: 0.000000
# Epoch [27/100] | Loss: 0.056644 | Recon Loss: 0.056601 | KL Loss: 0.000000
# Epoch [28/100] | Loss: 0.056614 | Recon Loss: 0.056581 | KL Loss: 0.000000
# Epoch [29/100] | Loss: 0.056592 | Recon Loss: 0.056557 | KL Loss: 0.000000
# Epoch [30/100] | Loss: 0.056613 | Recon Loss: 0.056571 | KL Loss: 0.000000
# Epoch [31/100] | Loss: 0.056594 | Recon Loss: 0.056568 | KL Loss: 0.000000
# Epoch [32/100] | Loss: 0.056571 | Recon Loss: 0.056546 | KL Loss: 0.000000
# Epoch [33/100] | Loss: 0.056581 | Recon Loss: 0.056549 | KL Loss: 0.000000
# Epoch [34/100] | Loss: 0.056549 | Recon Loss: 0.056526 | KL Loss: 0.000000
# Epoch [35/100] | Loss: 0.056564 | Recon Loss: 0.056541 | KL Loss: 0.000000
# Epoch [36/100] | Loss: 0.056566 | Recon Loss: 0.056531 | KL Loss: 0.000000
# Epoch [37/100] | Loss: 0.056557 | Recon Loss: 0.056538 | KL Loss: 0.000000
# Epoch [38/100] | Loss: 0.056566 | Recon Loss: 0.056548 | KL Loss: 0.000000
# Epoch [39/100] | Loss: 0.056544 | Recon Loss: 0.056520 | KL Loss: 0.000000
# Epoch [40/100] | Loss: 0.056539 | Recon Loss: 0.056523 | KL Loss: 0.000000
# Epoch [41/100] | Loss: 0.056528 | Recon Loss: 0.056511 | KL Loss: 0.000000
# Epoch [42/100] | Loss: 0.056544 | Recon Loss: 0.056519 | KL Loss: 0.000000
# Epoch [43/100] | Loss: 0.056526 | Recon Loss: 0.056512 | KL Loss: 0.000000
# Epoch [44/100] | Loss: 0.056514 | Recon Loss: 0.056501 | KL Loss: 0.000000
# Epoch [45/100] | Loss: 0.056516 | Recon Loss: 0.056497 | KL Loss: 0.000000
# Epoch [46/100] | Loss: 0.056515 | Recon Loss: 0.056501 | KL Loss: 0.000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 14
#      11 total_val_recon_loss = 0
#      12 total_val_kl_loss = 0
# ---> 14 for HR, LR in train_loader:
#      15     optimizer.zero_grad()
#      17     recon_imgs, latents, condition = model(HR, LR)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\torch\utils\data\dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\torch\utils\data\dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File c:\Users\maxhe\Documents\Uni\Master\Veranstaltungen\Generative Neural Networks\Abschlussprojekt\SuperResolution\utils\datasets.py:80, in MNIST_SR.__getitem__(self, index)
#      78 HR = self.transform(self.HR_dataset[index])
#      79 LR = self.transform(self.LR_dataset[index])
# ---> 80 return HR.to(self.device), LR.to(self.device)
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), path)

# %%
model.load_state_dict(torch.load(path))
# Out:
# <All keys matched successfully>

# %%
#[1:]
x_vals = [i*10 for i in range(0,3)]
plt.plot(loss_list[1:], label='Total Loss')
plt.plot(recon_loss_list[1:], label='Reconstruction Loss')
plt.plot([l * kl_weight for l in kl_loss_list][1:], label='KL Loss')
# plt.plot(x_vals, val_loss_list, label='Val Total Loss')
# plt.plot(x_vals, val_recon_loss_list, label='Val Reconstruction Loss')
# plt.plot(x_vals, [l * kl_weight for l in val_kl_loss_list], label='Val KL Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot()
# Out:
# []

# %%
HR, LR = test_dataset.get_samples(1000)
SR = model.sample(LR)

# %%
num_samples = LR.size(0)

z = torch.zeros(num_samples, latent_dims[0]).to(device)
sampled_latents = [z]

condition = model.lr_encoder(LR)
SR = model.decoder(sampled_latents, condition)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 7
#       4 sampled_latents = [z]
#       6 condition = model.lr_encoder(LR)
# ----> 7 SR = model.decoder(sampled_latents, condition)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# TypeError: ConditionalVAEDecoder.forward() takes 2 positional arguments but 3 were given

# %%
def show_image(x, low_res, superres, n):

    fig, axs = plt.subplots(3, n, figsize=(20, 6))
    for i in range(n):
        #figure description above every row in the middle
        if i == 0:
            axs[0, i].set_title('Original')
            axs[1, i].set_title('Low Resolution')
            axs[2, i].set_title('Super Resolution')

        axs[0, i].imshow(x[i].permute(1, 2, 0).detach().cpu().numpy(), cmap='gray')
        axs[0, i].axis('off')

        axs[1, i].imshow(low_res[i].permute(1, 2, 0).detach().cpu().numpy(), cmap='gray')
        axs[1, i].axis('off')

        axs[2, i].imshow(superres[i].permute(1, 2, 0).detach().cpu().numpy(), cmap='gray')
        axs[2, i].axis('off')

# %%
show_image(HR, LR, SR, 10)

# %%
n_samp = 3
offset = 7

for i in range(offset, n_samp + offset):
    reference = HR[i]
    reference = reference.repeat(batch_size, 1, 1, 1)
    reference_inp = LR[i].unsqueeze(0).repeat(batch_size, 1, 1, 1)
    
    samples = model.sample(reference_inp).detach().cpu()

    show_image(reference, reference_inp, samples, 10)

# %%
mse_val, perceptual_val, psnr_val, ssim_val, lpips_val, brisque_val, psnr_consistency_val, mse_diversity_val, lpips_diversity_val = validation_scores(model, HR, LR)
print("MSE:", mse_val)
print("Perceptual:", perceptual_val)
print("PSNR:", psnr_val)
print("SSIM:", ssim_val)
print("LPIPS:", lpips_val)
print("BRISQUE:", brisque_val)
print("PSNR Consistency:", psnr_consistency_val)
print("MSE Diversity:", mse_diversity_val)
print("LPIPS Diversity:", lpips_diversity_val)
# Out:
# c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# MSE: 0.005047918297350407
# Perceptual: 1.1069282293319702
# PSNR: 23.762866973876953
# SSIM: 0.9166612029075623
# LPIPS: 0.05779745802283287
# BRISQUE: 73.54656219482422
# PSNR Consistency: 36.83186721801758
# MSE Diversity: 1.2446589141568154e-06
# LPIPS Diversity: 2.9462336932795097e-05

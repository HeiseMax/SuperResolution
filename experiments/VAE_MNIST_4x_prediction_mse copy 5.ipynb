# %%
import torch
from torchinfo import summary
import torch.optim as optim
from torch.nn import MSELoss
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader


from utils.metrics import validation_scores
from models.prediction.VAE import ConditionalVAE
from utils.datasets import MNIST_SR
from utils.utils import gaussian_kl


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
num_epochs = 100
batch_size = 512
scalefactor = 4

path = f"trained_models/VAE_MNIST_{scalefactor}x_prediction_mse6.pth"

latent_dims = [32]
condition_dims = [16, 16]
channels = [4, 8, 16, 16]
cond_channels = [8, 16]
in_channels = 1
cond_base_width = 32 // scalefactor
model = ConditionalVAE(in_channels=in_channels,
                          latent_dims=latent_dims,
                          channels=channels,
                          cond_channels=cond_channels,
                          condition_dims=condition_dims,
                          cond_base_width=cond_base_width
                          ).to(device)
print(model.sample(torch.randn(1, in_channels, cond_base_width, cond_base_width).to(device)).shape)
summary(model, input_size=[(1, in_channels, 32, 32), (1, in_channels, cond_base_width, cond_base_width)])
# Out:
# torch.Size([1, 1, 32, 32])
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ConditionalVAE                           [1, 1, 32, 32]            --
# ├─ConditionalVAEEncoder: 1-1             [1, 32]                   --
# │    └─Conv2d: 2-1                       [1, 4, 32, 32]            8
# │    └─Conv2d: 2-2                       [1, 8, 16, 16]            520
# │    └─Conv2d: 2-3                       [1, 16, 8, 8]             2,064
# │    └─Conv2d: 2-4                       [1, 16, 4, 4]             4,112
# │    └─Linear: 2-5                       [1, 32]                   8,224
# │    └─Linear: 2-6                       [1, 32]                   8,224
# ├─ConditionalVAELREncoder: 1-2           [1, 16]                   --
# │    └─Conv2d: 2-7                       [1, 8, 8, 8]              16
# │    └─Conv2d: 2-8                       [1, 16, 4, 4]             2,064
# │    └─Linear: 2-9                       [1, 16]                   4,112
# │    └─Linear: 2-10                      [1, 16]                   8,208
# ├─ConditionalVAEDecoder: 1-3             [1, 1, 32, 32]            --
# │    └─Linear: 2-11                      [1, 256]                  8,448
# │    └─Linear: 2-12                      [1, 256]                  4,352
# │    └─Linear: 2-13                      [1, 1024]                 17,408
# │    └─ConvTranspose2d: 2-14             [1, 16, 8, 8]             4,112
# │    └─ConvTranspose2d: 2-15             [1, 8, 16, 16]            2,056
# │    └─ConvTranspose2d: 2-16             [1, 4, 32, 32]            516
# │    └─Conv2d: 2-17                      [1, 1, 32, 32]            5
# ==========================================================================================
# Total params: 74,449
# Trainable params: 74,449
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 1.76
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.14
# Params size (MB): 0.30
# Estimated Total Size (MB): 0.45
# ==========================================================================================

# %%
train_dataset = MNIST_SR(scale_factor=scalefactor, split='train')
test_dataset = MNIST_SR(scale_factor=scalefactor, split='test')

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
num_train_data = len(train_dataset)
print(f"Dataset Loaded: {len(train_dataset)} training samples, {len(test_dataset)} validation samples")
# Out:
# Dataset Loaded: 60000 training samples, 10000 validation samples

# %%
# Adam opt
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = MSELoss()
# Learning Rate Scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.9)

# %%
loss_list = []
recon_loss_list = []
kl_loss_list = []
val_loss_list = []
val_recon_loss_list = []
val_kl_loss_list = []

# %%
kl_weight = 1000

for epoch in range(num_epochs):
    model.train()
    
    total_loss = 0
    total_recon_loss = 0
    total_kl_loss = 0
    total_val_loss = 0
    total_val_recon_loss = 0
    total_val_kl_loss = 0

    for HR, LR in train_loader:
        optimizer.zero_grad()

        recon_imgs, latents = model(HR, LR)

        recon_loss = criterion(recon_imgs, HR)
        kl_loss = 0
        for mu, logvar in latents:
            kl_loss += torch.mean(gaussian_kl(mu, logvar, torch.zeros_like(mu), torch.zeros_like(logvar)))
        loss = recon_loss + kl_weight * kl_loss# * epoch*2

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        total_recon_loss += recon_loss.item()
        total_kl_loss += kl_loss.item()

    scheduler.step()

    if (epoch) % 10 == 0 or epoch == num_epochs-1:
        model.eval()
        with torch.no_grad():
            for HR, LR in val_loader:
                recon_imgs, latents = model(HR, LR)
                recon_loss = criterion(recon_imgs, HR)
                kl_loss = 0
                for mu, logvar in latents:
                    kl_loss += torch.mean(gaussian_kl(mu, logvar, torch.zeros_like(mu), torch.zeros_like(logvar)))
                loss = recon_loss + kl_weight * kl_loss

                total_val_loss += loss.item()
                total_val_recon_loss += recon_loss.item()
                total_val_kl_loss += kl_loss.item()

        total_val_loss /= len(val_loader)
        total_val_recon_loss /= len(val_loader)
        total_val_kl_loss /= len(val_loader)
        print(f"Validation Epoch [{epoch+1}/{num_epochs}] | Loss: {total_val_loss:.6f} | Recon Loss: {total_val_recon_loss:.6f} | KL Loss: {total_val_kl_loss:.6f}")
        val_loss_list.append(total_val_loss)
        val_recon_loss_list.append(total_val_recon_loss)
        val_kl_loss_list.append(total_val_kl_loss)

    total_loss /= len(train_loader)
    total_recon_loss /= len(train_loader)
    total_kl_loss /= len(train_loader)
    print(f"Epoch [{epoch+1}/{num_epochs}] | Loss: {total_loss:.6f} | Recon Loss: {total_recon_loss:.6f} | KL Loss: {total_kl_loss:.6f}")
    loss_list.append(total_loss)
    recon_loss_list.append(total_recon_loss)
    kl_loss_list.append(total_kl_loss)
# Out:
# Validation Epoch [1/100] | Loss: 0.065819 | Recon Loss: 0.058106 | KL Loss: 0.000008
# Epoch [1/100] | Loss: 0.229461 | Recon Loss: 0.116451 | KL Loss: 0.000113
# Epoch [2/100] | Loss: 0.062371 | Recon Loss: 0.057140 | KL Loss: 0.000005
# Epoch [3/100] | Loss: 0.059356 | Recon Loss: 0.056666 | KL Loss: 0.000003
# Epoch [4/100] | Loss: 0.058239 | Recon Loss: 0.056555 | KL Loss: 0.000002
# Epoch [5/100] | Loss: 0.057719 | Recon Loss: 0.056535 | KL Loss: 0.000001
# Epoch [6/100] | Loss: 0.057368 | Recon Loss: 0.056504 | KL Loss: 0.000001
# Epoch [7/100] | Loss: 0.057165 | Recon Loss: 0.056507 | KL Loss: 0.000001
# Epoch [8/100] | Loss: 0.057015 | Recon Loss: 0.056498 | KL Loss: 0.000001
# Epoch [9/100] | Loss: 0.056936 | Recon Loss: 0.056512 | KL Loss: 0.000000
# Epoch [10/100] | Loss: 0.056813 | Recon Loss: 0.056482 | KL Loss: 0.000000
# Validation Epoch [11/100] | Loss: 0.056941 | Recon Loss: 0.056698 | KL Loss: 0.000000
# Epoch [11/100] | Loss: 0.056768 | Recon Loss: 0.056492 | KL Loss: 0.000000
# Epoch [12/100] | Loss: 0.056750 | Recon Loss: 0.056493 | KL Loss: 0.000000
# Epoch [13/100] | Loss: 0.056679 | Recon Loss: 0.056492 | KL Loss: 0.000000
# Epoch [14/100] | Loss: 0.056631 | Recon Loss: 0.056474 | KL Loss: 0.000000
# Epoch [15/100] | Loss: 0.056616 | Recon Loss: 0.056478 | KL Loss: 0.000000
# Epoch [16/100] | Loss: 0.056581 | Recon Loss: 0.056470 | KL Loss: 0.000000
# Epoch [17/100] | Loss: 0.056559 | Recon Loss: 0.056461 | KL Loss: 0.000000
# Epoch [18/100] | Loss: 0.056579 | Recon Loss: 0.056475 | KL Loss: 0.000000
# Epoch [19/100] | Loss: 0.056557 | Recon Loss: 0.056488 | KL Loss: 0.000000
# Epoch [20/100] | Loss: 0.056535 | Recon Loss: 0.056478 | KL Loss: 0.000000
# Validation Epoch [21/100] | Loss: 0.056724 | Recon Loss: 0.056679 | KL Loss: 0.000000
# Epoch [21/100] | Loss: 0.056511 | Recon Loss: 0.056462 | KL Loss: 0.000000
# Epoch [22/100] | Loss: 0.056510 | Recon Loss: 0.056469 | KL Loss: 0.000000
# Epoch [23/100] | Loss: 0.056513 | Recon Loss: 0.056471 | KL Loss: 0.000000
# Epoch [24/100] | Loss: 0.056501 | Recon Loss: 0.056456 | KL Loss: 0.000000
# Epoch [25/100] | Loss: 0.056494 | Recon Loss: 0.056466 | KL Loss: 0.000000
# Epoch [26/100] | Loss: 0.056513 | Recon Loss: 0.056488 | KL Loss: 0.000000
# Epoch [27/100] | Loss: 0.056530 | Recon Loss: 0.056480 | KL Loss: 0.000000
# Epoch [28/100] | Loss: 0.056478 | Recon Loss: 0.056460 | KL Loss: 0.000000
# Epoch [29/100] | Loss: 0.056469 | Recon Loss: 0.056453 | KL Loss: 0.000000
# Epoch [30/100] | Loss: 0.056488 | Recon Loss: 0.056466 | KL Loss: 0.000000
# Validation Epoch [31/100] | Loss: 0.055064 | Recon Loss: 0.055051 | KL Loss: 0.000000
# Epoch [31/100] | Loss: 0.056118 | Recon Loss: 0.056104 | KL Loss: 0.000000
# Epoch [32/100] | Loss: 0.052510 | Recon Loss: 0.052488 | KL Loss: 0.000000
# Epoch [33/100] | Loss: 0.046340 | Recon Loss: 0.046315 | KL Loss: 0.000000
# Epoch [34/100] | Loss: 0.042893 | Recon Loss: 0.042881 | KL Loss: 0.000000
# Epoch [35/100] | Loss: 0.041606 | Recon Loss: 0.041593 | KL Loss: 0.000000
# Epoch [36/100] | Loss: 0.040726 | Recon Loss: 0.040700 | KL Loss: 0.000000
# Epoch [37/100] | Loss: 0.040101 | Recon Loss: 0.040089 | KL Loss: 0.000000
# Epoch [38/100] | Loss: 0.038708 | Recon Loss: 0.038693 | KL Loss: 0.000000
# Epoch [39/100] | Loss: 0.037090 | Recon Loss: 0.037068 | KL Loss: 0.000000
# Epoch [40/100] | Loss: 0.036227 | Recon Loss: 0.036217 | KL Loss: 0.000000
# Validation Epoch [41/100] | Loss: 0.034972 | Recon Loss: 0.034961 | KL Loss: 0.000000
# Epoch [41/100] | Loss: 0.035552 | Recon Loss: 0.035542 | KL Loss: 0.000000
# Epoch [42/100] | Loss: 0.033785 | Recon Loss: 0.033759 | KL Loss: 0.000000
# Epoch [43/100] | Loss: 0.032316 | Recon Loss: 0.032306 | KL Loss: 0.000000
# Epoch [44/100] | Loss: 0.030973 | Recon Loss: 0.030963 | KL Loss: 0.000000
# Epoch [45/100] | Loss: 0.029394 | Recon Loss: 0.029366 | KL Loss: 0.000000
# Epoch [46/100] | Loss: 0.027865 | Recon Loss: 0.027855 | KL Loss: 0.000000
# Epoch [47/100] | Loss: 0.025815 | Recon Loss: 0.025806 | KL Loss: 0.000000
# Epoch [48/100] | Loss: 0.023726 | Recon Loss: 0.023711 | KL Loss: 0.000000
# Epoch [49/100] | Loss: 0.022005 | Recon Loss: 0.021995 | KL Loss: 0.000000
# Epoch [50/100] | Loss: 0.020755 | Recon Loss: 0.020748 | KL Loss: 0.000000
# Validation Epoch [51/100] | Loss: 0.019197 | Recon Loss: 0.019190 | KL Loss: 0.000000
# Epoch [51/100] | Loss: 0.019914 | Recon Loss: 0.019896 | KL Loss: 0.000000
# Epoch [52/100] | Loss: 0.019192 | Recon Loss: 0.019186 | KL Loss: 0.000000
# Epoch [53/100] | Loss: 0.018610 | Recon Loss: 0.018604 | KL Loss: 0.000000
# Epoch [54/100] | Loss: 0.018141 | Recon Loss: 0.018128 | KL Loss: 0.000000
# Epoch [55/100] | Loss: 0.017757 | Recon Loss: 0.017749 | KL Loss: 0.000000
# Epoch [56/100] | Loss: 0.017417 | Recon Loss: 0.017414 | KL Loss: 0.000000
# Epoch [57/100] | Loss: 0.017128 | Recon Loss: 0.017114 | KL Loss: 0.000000
# Epoch [58/100] | Loss: 0.016832 | Recon Loss: 0.016828 | KL Loss: 0.000000
# Epoch [59/100] | Loss: 0.016570 | Recon Loss: 0.016563 | KL Loss: 0.000000
# Epoch [60/100] | Loss: 0.016308 | Recon Loss: 0.016295 | KL Loss: 0.000000
# Validation Epoch [61/100] | Loss: 0.015668 | Recon Loss: 0.015666 | KL Loss: 0.000000
# Epoch [61/100] | Loss: 0.016088 | Recon Loss: 0.016084 | KL Loss: 0.000000
# Epoch [62/100] | Loss: 0.015874 | Recon Loss: 0.015871 | KL Loss: 0.000000
# Epoch [63/100] | Loss: 0.015691 | Recon Loss: 0.015679 | KL Loss: 0.000000
# Epoch [64/100] | Loss: 0.015507 | Recon Loss: 0.015500 | KL Loss: 0.000000
# Epoch [65/100] | Loss: 0.015361 | Recon Loss: 0.015358 | KL Loss: 0.000000
# Epoch [66/100] | Loss: 0.015212 | Recon Loss: 0.015202 | KL Loss: 0.000000
# Epoch [67/100] | Loss: 0.015069 | Recon Loss: 0.015063 | KL Loss: 0.000000
# Epoch [68/100] | Loss: 0.014936 | Recon Loss: 0.014933 | KL Loss: 0.000000
# Epoch [69/100] | Loss: 0.014822 | Recon Loss: 0.014808 | KL Loss: 0.000000
# Epoch [70/100] | Loss: 0.014706 | Recon Loss: 0.014703 | KL Loss: 0.000000
# Validation Epoch [71/100] | Loss: 0.014218 | Recon Loss: 0.014214 | KL Loss: 0.000000
# Epoch [71/100] | Loss: 0.014578 | Recon Loss: 0.014575 | KL Loss: 0.000000
# Epoch [72/100] | Loss: 0.014465 | Recon Loss: 0.014455 | KL Loss: 0.000000
# Epoch [73/100] | Loss: 0.014368 | Recon Loss: 0.014364 | KL Loss: 0.000000
# Epoch [74/100] | Loss: 0.014269 | Recon Loss: 0.014265 | KL Loss: 0.000000
# Epoch [75/100] | Loss: 0.014193 | Recon Loss: 0.014182 | KL Loss: 0.000000
# Epoch [76/100] | Loss: 0.014100 | Recon Loss: 0.014096 | KL Loss: 0.000000
# Epoch [77/100] | Loss: 0.014026 | Recon Loss: 0.014022 | KL Loss: 0.000000
# Epoch [78/100] | Loss: 0.013961 | Recon Loss: 0.013953 | KL Loss: 0.000000
# Epoch [79/100] | Loss: 0.013896 | Recon Loss: 0.013891 | KL Loss: 0.000000
# Epoch [80/100] | Loss: 0.013832 | Recon Loss: 0.013828 | KL Loss: 0.000000
# Validation Epoch [81/100] | Loss: 0.013445 | Recon Loss: 0.013437 | KL Loss: 0.000000
# Epoch [81/100] | Loss: 0.013780 | Recon Loss: 0.013770 | KL Loss: 0.000000
# Epoch [82/100] | Loss: 0.013717 | Recon Loss: 0.013712 | KL Loss: 0.000000
# Epoch [83/100] | Loss: 0.013677 | Recon Loss: 0.013672 | KL Loss: 0.000000
# Epoch [84/100] | Loss: 0.013630 | Recon Loss: 0.013619 | KL Loss: 0.000000
# Epoch [85/100] | Loss: 0.013580 | Recon Loss: 0.013574 | KL Loss: 0.000000
# Epoch [86/100] | Loss: 0.013525 | Recon Loss: 0.013521 | KL Loss: 0.000000
# Epoch [87/100] | Loss: 0.013507 | Recon Loss: 0.013499 | KL Loss: 0.000000
# Epoch [88/100] | Loss: 0.013454 | Recon Loss: 0.013449 | KL Loss: 0.000000
# Epoch [89/100] | Loss: 0.013428 | Recon Loss: 0.013425 | KL Loss: 0.000000
# Epoch [90/100] | Loss: 0.013394 | Recon Loss: 0.013382 | KL Loss: 0.000000
# Validation Epoch [91/100] | Loss: 0.013041 | Recon Loss: 0.013038 | KL Loss: 0.000000
# Epoch [91/100] | Loss: 0.013350 | Recon Loss: 0.013347 | KL Loss: 0.000000
# Epoch [92/100] | Loss: 0.013320 | Recon Loss: 0.013318 | KL Loss: 0.000000
# Epoch [93/100] | Loss: 0.013301 | Recon Loss: 0.013291 | KL Loss: 0.000000
# Epoch [94/100] | Loss: 0.013267 | Recon Loss: 0.013263 | KL Loss: 0.000000
# Epoch [95/100] | Loss: 0.013244 | Recon Loss: 0.013241 | KL Loss: 0.000000
# Epoch [96/100] | Loss: 0.013226 | Recon Loss: 0.013216 | KL Loss: 0.000000
# Epoch [97/100] | Loss: 0.013192 | Recon Loss: 0.013187 | KL Loss: 0.000000
# Epoch [98/100] | Loss: 0.013168 | Recon Loss: 0.013165 | KL Loss: 0.000000
# Epoch [99/100] | Loss: 0.013152 | Recon Loss: 0.013142 | KL Loss: 0.000000
# Validation Epoch [100/100] | Loss: 0.012827 | Recon Loss: 0.012823 | KL Loss: 0.000000
# Epoch [100/100] | Loss: 0.013133 | Recon Loss: 0.013130 | KL Loss: 0.000000

# %%
torch.save(model.state_dict(), path)

# %%
model.load_state_dict(torch.load(path))
# Out:
# <All keys matched successfully>

# %%
#[1:]
x_vals = [i*10 for i in range(0,10)]
plt.plot(loss_list[2:], label='Total Loss')
# plt.plot(recon_loss_list[2:], label='Reconstruction Loss')
# plt.plot([l * kl_weight for l in kl_loss_list][2:], label='KL Loss')
plt.plot(x_vals, val_loss_list[1:], label='Val Total Loss')
# plt.plot(x_vals, val_recon_loss_list[1:], label='Val Reconstruction Loss')
# plt.plot(x_vals, [l * kl_weight for l in val_kl_loss_list][1:], label='Val KL Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot()
# Out:
# []

# %%
HR, LR = test_dataset.get_samples(1000)
SR = model.sample(LR)

# %%
num_samples = LR.size(0)

z = torch.rand(num_samples, latent_dims[0]).to(device) *5
sampled_latents = [z]

condition = model.lr_encoder(LR)
SR = model.decoder(sampled_latents, condition)

# %%
def show_image(x, low_res, superres, n):

    fig, axs = plt.subplots(3, n, figsize=(20, 6))
    for i in range(n):
        #figure description above every row in the middle
        if i == 0:
            axs[0, i].set_title('Original')
            axs[1, i].set_title('Low Resolution')
            axs[2, i].set_title('Super Resolution')

        axs[0, i].imshow(x[i].permute(1, 2, 0).detach().cpu().numpy(), cmap='gray')
        axs[0, i].axis('off')

        axs[1, i].imshow(low_res[i].permute(1, 2, 0).detach().cpu().numpy(), cmap='gray')
        axs[1, i].axis('off')

        axs[2, i].imshow(superres[i].permute(1, 2, 0).detach().cpu().numpy(), cmap='gray')
        axs[2, i].axis('off')

# %%
show_image(HR, LR, SR, 10)

# %%
n_samp = 3
offset = 7

for i in range(offset, n_samp + offset):
    reference = HR[i]
    reference = reference.repeat(batch_size, 1, 1, 1)
    reference_inp = LR[i].unsqueeze(0).repeat(batch_size, 1, 1, 1)
    
    samples = model.sample(reference_inp).detach().cpu()

    show_image(reference, reference_inp, samples, 10)

# %%
mse_val, perceptual_val, psnr_val, ssim_val, lpips_val, brisque_val, psnr_consistency_val, mse_diversity_val, lpips_diversity_val = validation_scores(model, HR, LR)
print("MSE:", mse_val)
print("Perceptual:", perceptual_val)
print("PSNR:", psnr_val)
print("SSIM:", ssim_val)
print("LPIPS:", lpips_val)
print("BRISQUE:", brisque_val)
print("PSNR Consistency:", psnr_consistency_val)
print("MSE Diversity:", mse_diversity_val)
print("LPIPS Diversity:", lpips_diversity_val)
# Out:
# c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\maxhe\anaconda3\envs\ML\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# MSE: 0.009209264069795609
# Perceptual: 1.824582815170288
# PSNR: 21.016307830810547
# SSIM: 0.8486267924308777
# LPIPS: 0.09026752412319183
# BRISQUE: 75.12137603759766
# PSNR Consistency: 32.048892974853516
# MSE Diversity: 0.0001147037479967139
# LPIPS Diversity: 0.0021034332194176386

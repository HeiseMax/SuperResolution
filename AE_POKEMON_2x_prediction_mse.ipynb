# %%
import torch
from torchinfo import summary
import torch.optim as optim
from torch.nn import MSELoss
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import models
import torch.nn.functional as nnf
import torch.nn as nn
from torchvision import transforms
from piq import psnr, ssim, brisque, LPIPS

from utils.metrics import validation_scores
from models.prediction.AE import AE256
from utils.datasets import Pokemon_SR_completion


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
num_epochs = 500
batch_size = 16
scalefactor = 8
latent_dims = [64]
channels = [32, 64, 128, 256]
in_channels = 3
base_width = 32
model = AE256(in_channels=in_channels,
                          latent_dims=latent_dims,
                          channels=channels,
                          base_width=base_width
                          ).to(device)
print(model.sample(torch.randn(1, in_channels, base_width, base_width).to(device)).shape)
summary(model, input_size=(1, in_channels, base_width, base_width))
# Out:
# torch.Size([1, 3, 256, 256])
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# AE                                       [1, 3, 256, 256]          --
# ├─AELREncoder: 1-1                       [1, 64]                   --
# │    └─Conv2d: 2-1                       [1, 32, 32, 32]           128
# │    └─Conv2d: 2-2                       [1, 64, 16, 16]           32,832
# │    └─Conv2d: 2-3                       [1, 128, 8, 8]            131,200
# │    └─Linear: 2-4                       [1, 64]                   524,352
# ├─AEDecoder: 1-2                         [1, 3, 256, 256]          --
# │    └─Linear: 2-5                       [1, 262144]               17,039,360
# │    └─ConvTranspose2d: 2-6              [1, 128, 64, 64]          524,416
# │    └─ConvTranspose2d: 2-7              [1, 64, 128, 128]         131,136
# │    └─ConvTranspose2d: 2-8              [1, 32, 256, 256]         32,800
# │    └─Conv2d: 2-9                       [1, 3, 256, 256]          99
# ==========================================================================================
# Total params: 18,416,323
# Trainable params: 18,416,323
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 6.49
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 33.49
# Params size (MB): 73.67
# Estimated Total Size (MB): 107.17
# ==========================================================================================

# %%
train_dataset = Pokemon_SR_completion(scale_factor=scalefactor, split='train')
test_dataset = Pokemon_SR_completion(scale_factor=scalefactor, split='test')

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
num_train_data = len(train_dataset)
print(f"Dataset Loaded: {len(train_dataset)} training samples, {len(test_dataset)} validation samples")
plt.imshow(train_dataset[0][0].permute(1, 2, 0).cpu().numpy())
#means = []
#stds = []
#for img in train_loader:
#    means.append(torch.mean(img[1]))
#    stds.append(torch.std(img[1]))

#mean = torch.mean(torch.tensor(means))
#std = torch.mean(torch.tensor(stds))
# Out:
# Dataset Loaded: 655 training samples, 164 validation samples

# %%
# Adam opt
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.MSELoss()
# Learning Rate Scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.9)

# %%
for epoch in range(num_epochs):
    model.train()
    total_loss = 0


    for HR, LR, LR_UP in train_loader:

        optimizer.zero_grad()
        recon_imgs = model(LR)
        #plt.imshow(HR[0].permute(1, 2, 0).detach().cpu().numpy())
        #plt.show()
        #normalize = transforms.Normalize(mean=[0.49139968, 0.48215841, 0.44653091], std=[0.24703223, 0.24348513, 0.26158784])
        #HR = normalize(HR)
        #HR = transforms.Resize((224, 224))(HR)
        #recon_imgs = normalize(recon_imgs)
        #recon_imgs = transforms.Resize((224, 224))(recon_imgs)
        #loss = ssim(recon_imgs, HR)
        loss = criterion(recon_imgs, HR)
        #loss = -loss
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    scheduler.step()

    print(f"Epoch [{epoch+1}/{num_epochs}] | Loss: {total_loss:.2f}")
    model.loss.append(total_loss)
# Out:
# Epoch [1/500] | Loss: 3.80
# Epoch [2/500] | Loss: 3.10
# Epoch [3/500] | Loss: 2.56
# Epoch [4/500] | Loss: 2.20
# Epoch [5/500] | Loss: 1.95
# Epoch [6/500] | Loss: 1.76
# Epoch [7/500] | Loss: 1.60
# Epoch [8/500] | Loss: 1.49
# Epoch [9/500] | Loss: 1.40
# Epoch [10/500] | Loss: 1.27
# Epoch [11/500] | Loss: 1.15
# Epoch [12/500] | Loss: 1.06
# Epoch [13/500] | Loss: 1.00
# Epoch [14/500] | Loss: 0.90
# Epoch [15/500] | Loss: 0.80
# Epoch [16/500] | Loss: 0.73
# Epoch [17/500] | Loss: 0.67
# Epoch [18/500] | Loss: 0.63
# Epoch [19/500] | Loss: 0.60
# Epoch [20/500] | Loss: 0.57
# Epoch [21/500] | Loss: 0.54
# Epoch [22/500] | Loss: 0.53
# Epoch [23/500] | Loss: 0.51
# Epoch [24/500] | Loss: 0.49
# Epoch [25/500] | Loss: 0.47
# Epoch [26/500] | Loss: 0.46
# Epoch [27/500] | Loss: 0.45
# Epoch [28/500] | Loss: 0.43
# Epoch [29/500] | Loss: 0.41
# Epoch [30/500] | Loss: 0.40
# Epoch [31/500] | Loss: 0.39
# Epoch [32/500] | Loss: 0.38
# Epoch [33/500] | Loss: 0.37
# Epoch [34/500] | Loss: 0.37
# Epoch [35/500] | Loss: 0.36
# Epoch [36/500] | Loss: 0.35
# Epoch [37/500] | Loss: 0.35
# Epoch [38/500] | Loss: 0.34
# Epoch [39/500] | Loss: 0.34
# Epoch [40/500] | Loss: 0.33
# Epoch [41/500] | Loss: 0.33
# Epoch [42/500] | Loss: 0.33
# Epoch [43/500] | Loss: 0.32
# Epoch [44/500] | Loss: 0.32
# Epoch [45/500] | Loss: 0.31
# Epoch [46/500] | Loss: 0.31
# Epoch [47/500] | Loss: 0.31
# Epoch [48/500] | Loss: 0.30
# Epoch [49/500] | Loss: 0.30
# Epoch [50/500] | Loss: 0.30
# Epoch [51/500] | Loss: 0.30
# Epoch [52/500] | Loss: 0.30
# Epoch [53/500] | Loss: 0.29
# Epoch [54/500] | Loss: 0.29
# Epoch [55/500] | Loss: 0.29
# Epoch [56/500] | Loss: 0.29
# Epoch [57/500] | Loss: 0.29
# Epoch [58/500] | Loss: 0.28
# Epoch [59/500] | Loss: 0.28
# Epoch [60/500] | Loss: 0.28
# Epoch [61/500] | Loss: 0.28
# Epoch [62/500] | Loss: 0.28
# Epoch [63/500] | Loss: 0.28
# Epoch [64/500] | Loss: 0.28
# Epoch [65/500] | Loss: 0.27
# Epoch [66/500] | Loss: 0.27
# Epoch [67/500] | Loss: 0.27
# Epoch [68/500] | Loss: 0.27
# Epoch [69/500] | Loss: 0.27
# Epoch [70/500] | Loss: 0.27
# Epoch [71/500] | Loss: 0.27
# Epoch [72/500] | Loss: 0.27
# Epoch [73/500] | Loss: 0.26
# Epoch [74/500] | Loss: 0.26
# Epoch [75/500] | Loss: 0.26
# Epoch [76/500] | Loss: 0.26
# Epoch [77/500] | Loss: 0.26
# Epoch [78/500] | Loss: 0.26
# Epoch [79/500] | Loss: 0.26
# Epoch [80/500] | Loss: 0.26
# Epoch [81/500] | Loss: 0.26
# Epoch [82/500] | Loss: 0.26
# Epoch [83/500] | Loss: 0.26
# Epoch [84/500] | Loss: 0.26
# Epoch [85/500] | Loss: 0.26
# Epoch [86/500] | Loss: 0.26
# Epoch [87/500] | Loss: 0.25
# Epoch [88/500] | Loss: 0.25
# Epoch [89/500] | Loss: 0.25
# Epoch [90/500] | Loss: 0.25
# Epoch [91/500] | Loss: 0.25
# Epoch [92/500] | Loss: 0.25
# Epoch [93/500] | Loss: 0.25
# Epoch [94/500] | Loss: 0.25
# Epoch [95/500] | Loss: 0.25
# Epoch [96/500] | Loss: 0.25
# Epoch [97/500] | Loss: 0.25
# Epoch [98/500] | Loss: 0.25
# Epoch [99/500] | Loss: 0.25
# Epoch [100/500] | Loss: 0.25
# Epoch [101/500] | Loss: 0.25
# Epoch [102/500] | Loss: 0.25
# Epoch [103/500] | Loss: 0.25
# Epoch [104/500] | Loss: 0.25
# Epoch [105/500] | Loss: 0.25
# Epoch [106/500] | Loss: 0.25
# Epoch [107/500] | Loss: 0.25
# Epoch [108/500] | Loss: 0.25
# Epoch [109/500] | Loss: 0.25
# Epoch [110/500] | Loss: 0.24
# Epoch [111/500] | Loss: 0.24
# Epoch [112/500] | Loss: 0.24
# Epoch [113/500] | Loss: 0.24
# Epoch [114/500] | Loss: 0.24
# Epoch [115/500] | Loss: 0.24
# Epoch [116/500] | Loss: 0.24
# Epoch [117/500] | Loss: 0.24
# Epoch [118/500] | Loss: 0.24
# Epoch [119/500] | Loss: 0.24
# Epoch [120/500] | Loss: 0.24
# Epoch [121/500] | Loss: 0.24
# Epoch [122/500] | Loss: 0.24
# Epoch [123/500] | Loss: 0.24
# Epoch [124/500] | Loss: 0.24
# Epoch [125/500] | Loss: 0.24
# Epoch [126/500] | Loss: 0.24
# Epoch [127/500] | Loss: 0.24
# Epoch [128/500] | Loss: 0.24
# Epoch [129/500] | Loss: 0.24
# Epoch [130/500] | Loss: 0.24
# Epoch [131/500] | Loss: 0.24
# Epoch [132/500] | Loss: 0.24
# Epoch [133/500] | Loss: 0.24
# Epoch [134/500] | Loss: 0.24
# Epoch [135/500] | Loss: 0.24
# Epoch [136/500] | Loss: 0.24
# Epoch [137/500] | Loss: 0.24
# Epoch [138/500] | Loss: 0.24
# Epoch [139/500] | Loss: 0.24
# Epoch [140/500] | Loss: 0.24
# Epoch [141/500] | Loss: 0.24
# Epoch [142/500] | Loss: 0.24
# Epoch [143/500] | Loss: 0.24
# Epoch [144/500] | Loss: 0.24
# Epoch [145/500] | Loss: 0.24
# Epoch [146/500] | Loss: 0.24
# Epoch [147/500] | Loss: 0.24
# Epoch [148/500] | Loss: 0.24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 23
#      20     loss.backward()
#      21     optimizer.step()
# ---> 23     total_loss += loss.item()
#      25 scheduler.step()
#      27 print(f"Epoch [{epoch+1}/{num_epochs}] | Loss: {total_loss:.2f}")
#
# KeyboardInterrupt:

# %%
plt.plot(model.loss)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot()
# Out:
# []

# %%
HR, LR, LR_UP = test_dataset.get_samples(32)
SR = model.sample(LR)

# %%
def show_image(x, low_res, superres, n):

    fig, axs = plt.subplots(4, n, figsize=(20, 6))
    for i in range(n):
        #figure description above every row in the middle
        if i == 0:
            axs[0, i].set_title('Original')
            axs[1, i].set_title('Low Resolution')
            axs[2, i].set_title('Super Resolution')
            axs[3, i].set_title('Low Resolution Upscaled')

        axs[0, i].imshow(x[i].permute(1, 2, 0).detach().cpu().numpy(),)
        axs[0, i].axis('off')

        axs[1, i].imshow(low_res[i].permute(1, 2, 0).detach().cpu().numpy())
        axs[1, i].axis('off')

        axs[2, i].imshow(superres[i].permute(1, 2, 0).detach().cpu().numpy())
        axs[2, i].axis('off')

        axs[3, i].imshow(LR_UP[i].permute(1, 2, 0).detach().cpu().numpy())
        axs[3, i].axis('off')

# %%
show_image(HR, LR, SR, 10)

# %%
_, _ , psnr_val, ssim_val, lpips_val, brisque_val, psnr_consistency_val, mse_diversity_val, lpips_diversity_val = validation_scores(model, HR, LR)
print("PSNR:", psnr_val)
print("SSIM:", ssim_val)
print("LPIPS:", lpips_val)
print("BRISQUE:", brisque_val)
print("PSNR Consistency:", psnr_consistency_val)
print("MSE Diversity:", mse_diversity_val)
print("LPIPS Diversity:", lpips_diversity_val)
# Out:
# c:\Users\Kevin\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Kevin\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 _, _ , psnr_val, ssim_val, lpips_val, brisque_val, psnr_consistency_val, mse_diversity_val, lpips_diversity_val = validation_scores(model, HR, LR)
#       2 print("PSNR:", psnr_val)
#       3 print("SSIM:", ssim_val)
#
# File c:\Users\Kevin\Desktop\Uni\GNN Project\SuperResolution\utils\metrics.py:46, in validation_scores(model, HR, LR, device)
#      44         SR_ref = SR_ref.repeat(n_samples, 1, 1, 1)
#      45         mse_diversity_val += F.mse_loss(SR_ref, SR, reduction='mean').item()
# ---> 46         lpips_diversity_val += lpips(SR_ref, SR).item()
#      47 mse_diversity_val /= n_iterations*n_samples
#      48 lpips_diversity_val /= n_iterations*n_samples
#
# File c:\Users\Kevin\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Kevin\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\Kevin\AppData\Local\Programs\Python\Python313\Lib\site-packages\piq\perceptual.py:178, in ContentLoss.forward(self, x, y)
#     176 self.model.to(x)
#     177 x_features = self.get_features(x)
# --> 178 y_features = self.get_features(y)
#     180 distances = self.compute_distance(x_features, y_features)
#     182 # Scale distances, then average in spatial dimensions, then stack and sum in channels dimension
#
# File c:\Users\Kevin\AppData\Local\Programs\Python\Python313\Lib\site-packages\piq\perceptual.py:208, in ContentLoss.get_features(self, x)
#     200 r"""
#     201 Args:
#     202     x: Tensor. Shape :math:`(N, C, H, W)`.
#    (...)    205     List of features extracted from intermediate layers
#     206 """
#     207 # Normalize input
# --> 208 x = (x - self.mean.to(x)) / self.std.to(x)
#     210 features = []
#     211 for name, module in self.model._modules.items():
#
# KeyboardInterrupt:

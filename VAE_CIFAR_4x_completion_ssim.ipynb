# %%
import torch
from torchinfo import summary
import torch.optim as optim
from torch.nn import MSELoss
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from piq import ssim


from utils.metrics import validation_scores
from models.completion.VAE import ConditionalVAE
from utils.datasets import CIFAR_SR_completion
from utils.utils import gaussian_kl


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
num_epochs = 100
batch_size = 512
scalefactor = 4

path = f"trained_models/VAE_CIFAR_{scalefactor}x_completion_ssim.pth"

latent_dims = [64]
condition_dims = [32, 64]
channels = [16, 32, 64, 128]
cond_channels = [16, 32]
in_channels = 3
cond_base_width = 32 // scalefactor
model = ConditionalVAE(in_channels=in_channels,
                          latent_dims=latent_dims,
                          channels=channels,
                          cond_channels=cond_channels,
                          condition_dims=condition_dims,
                          cond_base_width=cond_base_width
                          ).to(device)
print(model.sample(torch.randn(1, in_channels, cond_base_width, cond_base_width).to(device)).shape)
summary(model, input_size=[(1, in_channels, 32, 32), (1, in_channels, cond_base_width, cond_base_width), (1, in_channels, 32, 32)])
# Out:
# torch.Size([1, 3, 32, 32])
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ConditionalVAE                           [1, 3, 32, 32]            21
# ├─ConditionalVAEEncoder: 1-1             [1, 64]                   --
# │    └─Conv2d: 2-1                       [1, 16, 32, 32]           64
# │    └─Conv2d: 2-2                       [1, 32, 16, 16]           8,224
# │    └─Conv2d: 2-3                       [1, 64, 8, 8]             32,832
# │    └─Conv2d: 2-4                       [1, 128, 4, 4]            131,200
# │    └─Linear: 2-5                       [1, 64]                   131,136
# │    └─Linear: 2-6                       [1, 64]                   131,136
# ├─ConditionalVAELREncoder: 1-2           [1, 32]                   --
# │    └─Conv2d: 2-7                       [1, 16, 8, 8]             64
# │    └─Conv2d: 2-8                       [1, 32, 4, 4]             8,224
# │    └─Linear: 2-9                       [1, 32]                   16,416
# │    └─Linear: 2-10                      [1, 64]                   65,600
# ├─ConditionalVAEDecoder: 1-3             [1, 3, 32, 32]            --
# │    └─Linear: 2-11                      [1, 2048]                 133,120
# │    └─Linear: 2-12                      [1, 2048]                 67,584
# │    └─Linear: 2-13                      [1, 4096]                 266,240
# │    └─ConvTranspose2d: 2-14             [1, 64, 8, 8]             262,208
# │    └─ConvTranspose2d: 2-15             [1, 32, 16, 16]           65,568
# │    └─ConvTranspose2d: 2-16             [1, 16, 32, 32]           8,208
# │    └─Conv2d: 2-17                      [1, 3, 32, 32]            51
# ==========================================================================================
# Total params: 1,327,896
# Trainable params: 1,327,896
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 49.34
# ==========================================================================================
# Input size (MB): 0.03
# Forward/backward pass size (MB): 0.58
# Params size (MB): 5.31
# Estimated Total Size (MB): 5.92
# ==========================================================================================

# %%
train_dataset = CIFAR_SR_completion(scale_factor=scalefactor, split='train')
test_dataset = CIFAR_SR_completion(scale_factor=scalefactor, split='test')

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
num_train_data = len(train_dataset)
print(f"Dataset Loaded: {len(train_dataset)} training samples, {len(test_dataset)} validation samples")
# Out:
# Dataset Loaded: 50000 training samples, 10000 validation samples

# %%
# Adam opt
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = lambda x, y: -ssim(x, y)
# Learning Rate Scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.9)

# %%
loss_list = []
recon_loss_list = []
kl_loss_list = []

# %%
kl_weight = 1000

for epoch in range(num_epochs):
    model.train()
    
    total_loss = 0
    total_recon_loss = 0
    total_kl_loss = 0

    for HR, LR, LR_up in train_loader:
        optimizer.zero_grad()

        recon_imgs, latents = model(HR, LR, LR_up)

        recon_loss = criterion(recon_imgs, HR)
        kl_loss = 0
        for mu, logvar in latents:
            kl_loss += torch.mean(gaussian_kl(mu, logvar, torch.zeros_like(mu), torch.zeros_like(logvar)))
        loss = recon_loss + kl_weight * kl_loss

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        total_recon_loss += recon_loss.item()
        total_kl_loss += kl_loss.item()

    scheduler.step()    

    print(f"Epoch [{epoch+1}/{num_epochs}] | Loss: {total_loss:.6f} | Recon Loss: {total_recon_loss:.6f} | KL Loss: {total_kl_loss:.6f}")
    loss_list.append(total_loss)
    recon_loss_list.append(total_recon_loss)
    kl_loss_list.append(total_kl_loss)
# Out:
# Epoch [1/100] | Loss: 18.828425 | Recon Loss: -48.672767 | KL Loss: 0.067501
# Epoch [2/100] | Loss: -53.207444 | Recon Loss: -56.462493 | KL Loss: 0.003255
# Epoch [3/100] | Loss: -58.398448 | Recon Loss: -60.494300 | KL Loss: 0.002096
# Epoch [4/100] | Loss: -60.575837 | Recon Loss: -62.094415 | KL Loss: 0.001519
# Epoch [5/100] | Loss: -61.787996 | Recon Loss: -62.961668 | KL Loss: 0.001174
# Epoch [6/100] | Loss: -62.519617 | Recon Loss: -63.458708 | KL Loss: 0.000939
# Epoch [7/100] | Loss: -63.105722 | Recon Loss: -63.880165 | KL Loss: 0.000774
# Epoch [8/100] | Loss: -63.448052 | Recon Loss: -64.101724 | KL Loss: 0.000654
# Epoch [9/100] | Loss: -63.691020 | Recon Loss: -64.252829 | KL Loss: 0.000562
# Epoch [10/100] | Loss: -63.970636 | Recon Loss: -64.455848 | KL Loss: 0.000485
# Epoch [11/100] | Loss: -64.133149 | Recon Loss: -64.562395 | KL Loss: 0.000429
# Epoch [12/100] | Loss: -64.292124 | Recon Loss: -64.672942 | KL Loss: 0.000381
# Epoch [13/100] | Loss: -64.474211 | Recon Loss: -64.812762 | KL Loss: 0.000339
# Epoch [75/100] | Loss: -66.733108 | Recon Loss: -66.758142 | KL Loss: 0.000025
# Epoch [76/100] | Loss: -66.743928 | Recon Loss: -66.767707 | KL Loss: 0.000024
# Epoch [77/100] | Loss: -66.747602 | Recon Loss: -66.771014 | KL Loss: 0.000023
# Epoch [78/100] | Loss: -66.750433 | Recon Loss: -66.773903 | KL Loss: 0.000023
# Epoch [79/100] | Loss: -66.759768 | Recon Loss: -66.782481 | KL Loss: 0.000023
# Epoch [80/100] | Loss: -66.768530 | Recon Loss: -66.790597 | KL Loss: 0.000022
# Epoch [81/100] | Loss: -66.768501 | Recon Loss: -66.790832 | KL Loss: 0.000022
# Epoch [82/100] | Loss: -66.779897 | Recon Loss: -66.801390 | KL Loss: 0.000021
# Epoch [83/100] | Loss: -66.781655 | Recon Loss: -66.802526 | KL Loss: 0.000021
# Epoch [84/100] | Loss: -66.782913 | Recon Loss: -66.803634 | KL Loss: 0.000021
# Epoch [85/100] | Loss: -66.794080 | Recon Loss: -66.814199 | KL Loss: 0.000020
# Epoch [86/100] | Loss: -66.796759 | Recon Loss: -66.816611 | KL Loss: 0.000020
# Epoch [87/100] | Loss: -66.802300 | Recon Loss: -66.822105 | KL Loss: 0.000020
# Epoch [88/100] | Loss: -66.809241 | Recon Loss: -66.828349 | KL Loss: 0.000019
# Epoch [89/100] | Loss: -66.810280 | Recon Loss: -66.829105 | KL Loss: 0.000019
# Epoch [90/100] | Loss: -66.814913 | Recon Loss: -66.833475 | KL Loss: 0.000019
# Epoch [91/100] | Loss: -66.819788 | Recon Loss: -66.837945 | KL Loss: 0.000018
# Epoch [92/100] | Loss: -66.826778 | Recon Loss: -66.844726 | KL Loss: 0.000018
# Epoch [93/100] | Loss: -66.827475 | Recon Loss: -66.845146 | KL Loss: 0.000018
# Epoch [94/100] | Loss: -66.831283 | Recon Loss: -66.848505 | KL Loss: 0.000017
# Epoch [95/100] | Loss: -66.835982 | Recon Loss: -66.853162 | KL Loss: 0.000017
# Epoch [96/100] | Loss: -66.836382 | Recon Loss: -66.853421 | KL Loss: 0.000017
# Epoch [97/100] | Loss: -66.840589 | Recon Loss: -66.857025 | KL Loss: 0.000016
# Epoch [98/100] | Loss: -66.844205 | Recon Loss: -66.860367 | KL Loss: 0.000016
# Epoch [99/100] | Loss: -66.845310 | Recon Loss: -66.861409 | KL Loss: 0.000016
# Epoch [100/100] | Loss: -66.849752 | Recon Loss: -66.865448 | KL Loss: 0.000016

# %%
torch.save(model.state_dict(), path)

# %%
model.load_state_dict(torch.load(path))
# Out:
# <All keys matched successfully>

# %%
plt.plot(loss_list[1:], label='Total Loss')
plt.plot(recon_loss_list[1:], label='Reconstruction Loss')
plt.plot([l * kl_weight for l in kl_loss_list][1:], label='KL Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot()
# Out:
# []

# %%
HR, LR, LR_up = test_dataset.get_samples(1000)
SR = model.sample(LR)

# %%
def show_image(x, low_res, superres, n):

    fig, axs = plt.subplots(3, n, figsize=(20, 6))
    for i in range(n):
        #figure description above every row in the middle
        if i == 0:
            axs[0, i].set_title('Original')
            axs[1, i].set_title('Low Resolution')
            axs[2, i].set_title('Super Resolution')

        axs[0, i].imshow(x[i].permute(1, 2, 0).detach().cpu().numpy(),)
        axs[0, i].axis('off')

        axs[1, i].imshow(low_res[i].permute(1, 2, 0).detach().cpu().numpy())
        axs[1, i].axis('off')

        axs[2, i].imshow(superres[i].permute(1, 2, 0).detach().cpu().numpy())
        axs[2, i].axis('off')

# %%
show_image(HR, LR, SR, 10)

# %%
n_samp = 3

for i in range(n_samp):
    reference = HR[i]
    reference = reference.repeat(batch_size, 1, 1, 1)
    reference_inp = LR[i].unsqueeze(0).repeat(batch_size, 1, 1, 1)
    
    samples = model.sample(reference_inp).detach().cpu()

    show_image(reference, reference_inp, samples, 10)

# %%
# mse_val, perceptual_val, psnr_val, ssim_val, lpips_val, brisque_val, psnr_consistency_val, mse_diversity_val, lpips_diversity_val = validation_scores(model, HR, LR)
# print("MSE:", mse_val)
# print("Perceptual:", perceptual_val)
# print("PSNR:", psnr_val)
# print("SSIM:", ssim_val)
# print("LPIPS:", lpips_val)
# print("BRISQUE:", brisque_val)
# print("PSNR Consistency:", psnr_consistency_val)
# print("MSE Diversity:", mse_diversity_val)
# print("LPIPS Diversity:", lpips_diversity_val)
